# %%
# %load_ext autoreload
# %autoreload 2

# %%
from typing import Generator, Any
import pandas as pd
import json
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
from dotenv import load_dotenv
import os
from rich import print as rprint
from mbay_nmt.utils import domain as d
from mbay_nmt.utils.models import new_object_id
from datasets import load_dataset, Dataset, DatasetDict
from rich import print as rprint

load_dotenv()
# Out:
# True

# %%
uri = os.environ["MONGODB_URI"]

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi("1"))

# Send a ping to confirm a successful connection
try:
    client.admin.command("ping")
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
entries = client.get_database("dictionary").get_collection("entries")

# %%
def find_word(word: str):
    result = entries.find_one({"headword": word})
    if not result:
        return None

    return {
        "headword": result["headword"],
        "french": result["french"]["translation"],
        "english": result["english"]["translation"],
    }

# %%
find_word("már")
# Out:
# {'headword': 'már',
#  'french': 'complètement (noir)',
#  'english': 'completely (black).'}

# %%
from oauth2client.service_account import ServiceAccountCredentials

# Use the JSON key file you downloaded when you created your Service Account
json_key_file = "/Users/nasoungadoy/.googlecloud/fluid-mind-303321-602c5b57c4e7.json"

# Define the scope
scope = [
    "https://spreadsheets.google.com/feeds",
    "https://www.googleapis.com/auth/drive",
]

# %%
import gspread

# Load the credentials and create a client to interact with the Google Drive API
credentials = ServiceAccountCredentials.from_json_keyfile_name(json_key_file, scope)
google_sheets = gspread.authorize(credentials)

# %%
# Out:
# {'id': 0,
#  'entry_id': 1,
#  'type': 2,
#  'mbay': 3,
#  'french': 4,
#  'english': 5,
#  'flagged': 6,
#  'comment': 7}

# %%
sheet = google_sheets.open_by_url(
    "https://docs.google.com/spreadsheets/d/1KbpQS0RdcLhUOJNFNdXlnTDZBKEU2S8Q7DnJhPYrr2M"
).sheet1
columns = sheet.row_values(1)
columns = {columns[i]: i + 1 for i in range(len(columns))}
columns
# Out:
# {'id': 1,
#  'entry_id': 2,
#  'type': 3,
#  'mbay': 4,
#  'french': 5,
#  'english': 6,
#  'flagged': 7,
#  'comment': 8}

# %%
sheet.cell(1, columns["mbay"]).value
# Out:
# 'mbay'

# %%
for row_id, v in enumerate(["a", "b", "c"], start=1):
    print(row_id, v)
# Out:
# 1 a
# 2 b
# 3 c

# %%
from langdetect import detect, detect_langs

# %%
from ratelimit import limits
from gspread import Cell


@limits(calls=60, period=60)
def update_cell(sheet: gspread.Worksheet, row_id: int, col_id: int, value: Any):
    sheet.update_cell(row_id, col_id, value)


def fix_ibid(sheet: gspread.Worksheet, record: dict[str, str], row_id: int):
    entry = find_word(record["mbay"])
    if not entry:
        print(f"Could not find {record['mbay']}")
        update_cell(sheet, row_id, columns["flagged"], True)
        update_cell(sheet, row_id, columns["comment"], "could not find in Morkeg")
        return

    update_cell(sheet, row_id, columns["english"], entry["english"])
    update_cell(sheet, row_id, columns["french"], entry["french"])


def fix_ibid2(cells: list[Cell], record: dict[str, str], row_id: int):
    entry = find_word(record["mbay"])
    if not entry:
        print(f"Could not find {record['mbay']}")
        cells.append(Cell(row_id, columns["flagged"], True))
        cells.append(Cell(row_id, columns["comment"], "could not find in Morkeg"))
        return

    cells.append(Cell(row_id, columns["english"], entry["english"]))
    cells.append(Cell(row_id, columns["french"], entry["french"]))

# %%
# Get all records of the data
records = sheet.get_all_records()
cells = []
# Iterate over the rows
for row_id, record in enumerate(records, start=2):
    if "ibid" in record["english"] or "ibid" in record["french"]:
        fix_ibid2(cells, record, row_id)
# Out:
# Could not find délɨ́l
# Could not find yɨ̀nè

# %%
cells
# Out:
# [<Cell R8527C6 'clearly, carefully (see, understand, examine).'>,
#  <Cell R8527C5 'clairement, attentivement (voir, comprendre, examiner)'>,
#  <Cell R8529C6 'plump, round and (fat) {birds}.'>,
#  <Cell R8529C5 'oiseaux dodus, ronds et (gras)'>,
#  <Cell R8530C6 'be large and ugly.'>,
#  <Cell R8530C5 'être grand et laid.'>,
#  <Cell R8531C6 'loudly (cough).'>,
#  <Cell R8531C5 'fort (toux).'>,
#  <Cell R8536C6 'repetitively, nonsensically (talk).'>,
#  <Cell R8536C5 'de manière répétitive, sans aucun sens (parler)'>,
#  <Cell R8538C6 'extremely (soft {fruit}).'>,
#  <Cell R8538C5 'extrêmement (fruit doux)'>,
#  <Cell R8540C6 'hard to the ground (knock down).'>,
#  <Cell R8540C5 'difficile au sol (renverser)'>,
#  <Cell R8543C6 'fragrant (smell).'>,
#  <Cell R8543C5 'parfumé (odeur).'>,
#  <Cell R8544C6 'heavily (fall) {living creature, as snake from a tree}.'>,
#  <Cell R8544C5 "lourdement (tomber) {être vivant, comme un serpent d'un arbre}">,
#  <Cell R8545C6 '(heavy) and hanging.'>,
#  <Cell R8545C5 '(lourd) et suspendu.'>,
#  <Cell R8548C6 'folded and (wide).'>,
#  <Cell R8548C5 'plié et (large).'>,
#  <Cell R8549C6 'pleasantly (cool).'>,
#  <Cell R8549C5 'agréablement (frais)'>,
#  <Cell R8551C6 'rapidly (swish to cool).'>,
#  <Cell R8551C5 'rapidement (mouvement de balayage pour refroidir)'>,
#  <Cell R8553C6 'carefully (separate).'>,
#  <Cell R8553C5 'soigneusement (séparé)'>,
#  <Cell R8554C6 'stretched and (shrunk).'>,
#  <Cell R8554C5 'étiré et rétréci.'>,
#  <Cell R8556C6 'perfectly (white).'>,
#  <Cell R8556C5 'parfaitement (blanc)'>,
#  <Cell R8560C6 'extremely (soft).'>,
#  <Cell R8560C5 'extrêmement doux'>,
#  <Cell R8568C6 'hard (scratch).'>,
#  <Cell R8568C5 'dur (gratter)'>,
#  <Cell R8569C6 'with a ripping sound (tear); badly (torn}.'>,
#  <Cell R8569C5 'avec un bruit de déchirure (déchirer); mal (déchiré).'>,
#  <Cell R8570C6 'completely (lifeless).'>,
#  <Cell R8570C5 'complètement (sans vie).'>,
#  <Cell R8573C6 'near, nearby.'>,
#  <Cell R8573C5 'proche, à proximité'>,
#  <Cell R8574C6 'round and about size of grapefruit.'>,
#  <Cell R8574C5 "rond et environ de la taille d'un pamplemousse.">,
#  <Cell R8575C6 'hard (hit with, chop).'>,
#  <Cell R8575C5 'dur (frapper avec, hacher).'>,
#  <Cell R8577C6 'with a flick (brush off,sweep).'>,
#  <Cell R8577C5 'avec un geste (brosser, balayer).'>,
#  <Cell R8579C6 'completely (full).'>,
#  <Cell R8579C5 'complètement (plein)'>,
#  <Cell R8580C6 'extremely (fat).'>,
#  <Cell R8580C5 'extrêmement (gras)'>,
#  <Cell R8581C6 'completely (better, cured).'>,
#  <Cell R8581C5 'complètement (mieux, guéri)'>,
#  <Cell R8582C6 'hard (hit {with s.t.}).'>,
#  <Cell R8582C5 'dur (frapper {avec qqch})'>,
#  <Cell R8588C6 'badly (stab, pierce).'>,
#  <Cell R8588C5 'mal (poignarder, percer).'>,
#  <Cell R8589C6 'completely (pierced,cut,chopped, etc.).'>,
#  <Cell R8589C5 'complètement (percé, coupé, haché, etc.)'>,
#  <Cell R8592C6 'extremely (narrow, thin).'>,
#  <Cell R8592C5 'extrêmement (étroit, mince)'>,
#  <Cell R8593C6 "startled and momentarily unable to move (in expression rō [dèē] tùtɨ̀ à '[s.o.] be completely startled').">,
#  <Cell R8593C5 "effrayé et momentanément incapable de bouger (dans l'expression rō [dèē] tùtɨ̀ à '[qqn.] être complètement effrayé').">,
#  <Cell R8594C6 'completely (foam up, rise up).'>,
#  <Cell R8594C5 'complètement (mousser, monter)'>,
#  <Cell R8595C6 'perfectly (white).'>,
#  <Cell R8595C5 'parfaitement (blanc)'>,
#  <Cell R8596C6 'thoroughly (tied together) (desc. of ndà bɨ̀rà).'>,
#  <Cell R8596C5 'complètement (lié ensemble) (description de ndà bɨ̀rà).'>,
#  <Cell R8597C6 'hard (hit,punch).'>,
#  <Cell R8597C5 'coup dur (frapper, donner un coup de poing).'>,
#  <Cell R8600C6 'badly (bruised, etc.)'>,
#  <Cell R8600C5 'gravement (meurtri, etc.)'>,
#  <Cell R8604C6 'extremely (acidic, tangy).'>,
#  <Cell R8604C5 'extrêmement (acide, piquant)'>,
#  <Cell R8605C6 'badly (torn), in rags.'>,
#  <Cell R8605C5 'très abîmé, en lambeaux'>,
#  <Cell R8608C6 'to the top (fill {liquid}).'>,
#  <Cell R8608C5 'au sommet (remplir {liquide}).'>,
#  <Cell R8610C6 'extremely (sweet).'>,
#  <Cell R8610C5 'extrêmement (doux)'>,
#  <Cell R8611C6 'fiery (red) (desc. of kɨ̀rē).'>,
#  <Cell R8611C5 'ardent (rouge) (desc. de kɨ̀rē)'>,
#  <Cell R8612C6 'be extremely thin; extremely (thin).'>,
#  <Cell R8612C5 'être extrêmement mince ; extrêmement (mince)'>,
#  <Cell R8617C6 'finely grind (flour).'>,
#  <Cell R8617C5 'moudre finement (farine).'>,
#  <Cell R8618C6 'extremely (deep).'>,
#  <Cell R8618C5 'extrêmement (profond).'>,
#  <Cell R8619C6 'loudly (make noise; bark).'>,
#  <Cell R8619C5 'fort (faire du bruit; aboyer)'>,
#  <Cell R8620C6 'thoroughly (shrink, thin).'>,
#  <Cell R8620C5 'complètement (rétrécir, amincir)'>,
#  <Cell R8621C6 'in foam (rise up).'>,
#  <Cell R8621C5 "dans la mousse (s'élever)">,
#  <Cell R8623C6 'extremely (wide).'>,
#  <Cell R8623C5 'extrêmement (large)'>,
#  <Cell R8625C6 'loudly (roar, shout, etc.)'>,
#  <Cell R8625C5 'fortement (rugir, crier, etc.)'>,
#  <Cell R8626C6 'loudly (shout, cry out).'>,
#  <Cell R8626C5 "fortement (crier, s'écrier)">,
#  <Cell R8628C6 'thoroughly (wipe).'>,
#  <Cell R8628C5 'thoroughly (essuyer).'>,
#  <Cell R8631C6 'with difficulty, with the words not coming.'>,
#  <Cell R8631C5 'avec difficulté, les mots ne viennent pas'>,
#  <Cell R8633C6 'very (fat) and smooth.'>,
#  <Cell R8633C5 'très (gros) et lisse'>,
#  <Cell R8635C6 'perfectly (smooth).'>,
#  <Cell R8635C5 'parfaitement (lisse)'>,
#  <Cell R8637C6 'very (short).'>,
#  <Cell R8637C5 'très (court)'>,
#  <Cell R8638C6 'be resistant, hard to break through.'>,
#  <Cell R8638C5 'être résistant, difficile à traverser.'>,
#  <Cell R8639C6 'blankly (stare).'>,
#  <Cell R8639C5 'regarder fixement (sans expression)'>,
#  <Cell R8640C6 'completely (pull off, come off).'>,
#  <Cell R8640C5 'complètement (enlever, se détacher)'>,
#  <Cell R8642C6 'badly (stutter).'>,
#  <Cell R8642C5 'mal (bégayer)'>,
#  <Cell R8643C6 'firmly (stick).'>,
#  <Cell R8643C5 'fermement (coller)'>,
#  <Cell R8646C6 'numerous (in public place).'>,
#  <Cell R8646C5 'nombreux (dans un lieu public)'>,
#  <Cell R8647C6 'the right amount (cooked,ground,etc.).'>,
#  <Cell R8647C5 'la bonne quantité (cuit, moulu, etc.).'>,
#  <Cell R8648C6 'perfectly (cooked,ground,etc.).'>,
#  <Cell R8648C5 'parfaitement (cuit, moulu, etc.)'>,
#  <Cell R8652C6 'heavily (fall {heavy living thing}).'>,
#  <Cell R8652C5 'lourdement (tomber {chose lourde})'>,
#  <Cell R8655C7 True>,
#  <Cell R8655C8 'could not find in Morkeg'>,
#  <Cell R8658C6 'completely (pierced).'>,
#  <Cell R8658C5 'complètement (percé)'>,
#  <Cell R8659C6 'tightly (stuff {in single motion}).'>,
#  <Cell R8659C5 'étroitement (chose {en un seul mouvement}).'>,
#  <Cell R8661C6 'with no feeling, numb.'>,
#  <Cell R8661C5 'sans sensation, engourdi'>,
#  <Cell R8662C6 'extremely (full).'>,
#  <Cell R8662C5 'extrêmement (plein)'>,
#  <Cell R8666C6 'place of; absence of.'>,
#  <Cell R8666C5 'lieu de; absence de.'>,
#  <Cell R8667C6 'suddenly {break}.'>,
#  <Cell R8667C5 'soudainement {casser}.'>,
#  <Cell R8669C6 'without much noise (break, cut through).'>,
#  <Cell R8669C5 'sans beaucoup de bruit (casser, couper à travers).'>,
#  <Cell R8671C6 'twisting off (remove).'>,
#  <Cell R8671C5 'tordre pour enlever.'>,
#  <Cell R8672C6 'thoroughly (wrap [s.t. big]).'>,
#  <Cell R8672C5 'complètement (envelopper [qch de grand])'>,
#  <Cell R8673C6 'thoroughly (wrap [s.t. small]).'>,
#  <Cell R8673C5 'envelopper soigneusement (quelque chose de petit)'>,
#  <Cell R8674C6 'straight and (tall).'>,
#  <Cell R8674C5 'droit et (grand).'>,
#  <Cell R8675C6 'round and hard.'>,
#  <Cell R8675C5 'rond et dur'>,
#  <Cell R8676C6 'be short.'>,
#  <Cell R8676C5 'être court.'>,
#  <Cell R8677C6 'perfectly (ripe).'>,
#  <Cell R8677C5 'parfaitement (mûr).'>,
#  <Cell R8678C6 'obligatorily.'>,
#  <Cell R8678C5 'obligatoirement'>,
#  <Cell R8679C6 'hard to the ground (knock down).'>,
#  <Cell R8679C5 'dur au sol (renverser).'>,
#  <Cell R8680C6 'completely (pierced}.'>,
#  <Cell R8680C5 'complètement (percé)'>,
#  <Cell R8682C6 'without much force or noise (break).'>,
#  <Cell R8682C5 'sans beaucoup de force ou de bruit (casser).'>,
#  <Cell R8686C6 'long and ugly (snout).'>,
#  <Cell R8686C5 'long et laid (museau).'>,
#  <Cell R8687C6 'patiently (control self).'>,
#  <Cell R8687C5 'patiemment (contrôler soi-même)'>,
#  <Cell R8688C6 'perfectly (white).'>,
#  <Cell R8688C5 'parfaitement (blanc)'>,
#  <Cell R8689C6 'tightly (stuff {in single motion}).'>,
#  <Cell R8689C5 'étroitement (rembourrer {en un seul mouvement}).'>,
#  <Cell R8693C6 'with a snapping noise (whip, break).'>,
#  <Cell R8693C5 'avec un bruit sec (fouet, rupture).'>,
#  <Cell R8694C6 'be dull, blunt.'>,
#  <Cell R8694C5 'émoussé, émousser'>,
#  <Cell R8695C6 'vine.'>,
#  <Cell R8695C5 'vigne'>,
#  <Cell R8696C6 'with a snatch (take with fingers). ibid. (freq.,emph.).'>,
#  <Cell R8696C5 'avec une prise (prendre avec les doigts). ibid. (fréq., emph.)'>,
#  <Cell R8698C6 'extremely (wide).'>,
#  <Cell R8698C5 'extrêmement (large)'>,
#  <Cell R8701C6 'completely (twisted).'>,
#  <Cell R8701C5 'complètement (tordu)'>,
#  <Cell R8703C6 'extremely (sweet).'>,
#  <Cell R8703C5 'extrêmement (doux)'>,
#  <Cell R8704C6 'with a shock; with force (bump, crash).'>,
#  <Cell R8704C5 'avec un choc ; avec force (choc, crash).'>,
#  <Cell R8707C6 'with a bang (explode).'>,
#  <Cell R8707C5 'avec un bang (explosion)'>,
#  <Cell R8708C6 'badly (shrivel up, deformed).'>,
#  <Cell R8708C5 'mal (se flétrir, déformé).'>,
#  <Cell R8710C6 'with a thud (fall) {small animal or bird}.'>,
#  <Cell R8710C5 'avec un bruit sourd (tomber) {petit animal ou oiseau}.'>,
#  <Cell R8711C6 'with a thud (put/get down).'>,
#  <Cell R8711C5 'avec un bruit sourd (poser/déposer).'>,
#  <Cell R8716C6 'bad taste.'>,
#  <Cell R8716C5 'mauvais goût'>,
#  <Cell R8718C6 'off (black); very (angry).'>,
#  <Cell R8718C5 'éteint (noir) ; très (en colère)'>,
#  <Cell R8723C6 'very (big).'>,
#  <Cell R8723C5 'très (grand)'>,
#  <Cell R8724C6 'badly (split, cut {skin}).'>,
#  <Cell R8724C5 'mal (diviser, couper {peau}).'>,
#  <Cell R8726C6 'with fluttering sound.'>,
#  <Cell R8726C5 'avec un son de battement'>,
#  <Cell R8730C6 'extremely (sweet).'>,
#  <Cell R8730C5 'extrêmement (doux)'>,
#  <Cell R8733C6 'extremely (wide).'>,
#  <Cell R8733C5 'extrêmement (large)'>,
#  <Cell R8734C6 'extremely (rough and uneven).'>,
#  <Cell R8734C5 'extrêmement (rugueux et inégal)'>,
#  <Cell R8735C6 'heavily (fall) {person or animal}.'>,
#  <Cell R8735C5 'lourdement (tomber) {personne ou animal}'>,
#  <Cell R8737C6 'tightly (tie). ibid. (pl.,emph.). solidly (tied,closed).'>,
#  <Cell R8737C5 'étroitement (attacher). Ibid. (pl.,emph.). solidement (attaché, fermé).'>,
#  <Cell R8738C6 'completely (removed, broken, out of joint}.'>,
#  <Cell R8738C5 'complètement (enlevé, cassé, déboîté)'>,
#  <Cell R8740C6 'Bata - tiny Mbay subgroup; dialect very similar to dominant ɓēe-jùu dialect.'>,
#  <Cell R8740C5 'Bata - petit sous-groupe Mbay ; dialecte très similaire au dialecte dominant ɓēe-jùu.'>,
#  <Cell R8741C6 'tightly (tie).'>,
#  <Cell R8741C5 'étroitement (attacher)'>,
#  <Cell R8743C6 'suddenly and hard (fall, knock down}.'>,
#  <Cell R8743C5 'soudainement et fort (tomber, renverser)'>,
#  <Cell R8745C6 'in a tantrum.'>,
#  <Cell R8745C5 'dans une crise de colère.'>,
#  <Cell R8747C6 'ample, large (clothing).'>,
#  <Cell R8747C5 'ample, grand (vêtement)'>,
#  <Cell R8750C6 'completely (cracked, split,torn).'>,
#  <Cell R8750C5 'complètement (fissuré, fendu, déchiré).'>,
#  <Cell R8751C6 'missing target.'>,
#  <Cell R8751C5 'cible manquée'>,
#  <Cell R8754C6 'with a bang (explode, go off).'>,
#  <Cell R8754C5 'avec un bruit (exploser, détoner)'>,
#  <Cell R8756C6 'descriptive of wiping.'>,
#  <Cell R8756C5 "descriptif de l'essuyage.">,
#  <Cell R8757C6 'a lot (eat).'>,
#  <Cell R8757C5 'beaucoup (manger)'>,
#  <Cell R8759C6 'perfectly (white).'>,
#  <Cell R8759C5 'parfaitement (blanc)'>,
#  <Cell R8760C6 'in silence.'>,
#  <Cell R8760C5 'en silence'>,
#  <Cell R8761C6 'getting away (flee).'>,
#  <Cell R8761C5 "s'échapper (fuir)">,
#  <Cell R8762C6 'thoroughly (split).'>,
#  <Cell R8762C5 'en profondeur (divisé)'>,
#  <Cell R8767C6 'perfectly (even).'>,
#  <Cell R8767C5 'parfaitement (même)'>,
#  <Cell R8768C6 'gigantically (big).'>,
#  <Cell R8768C5 'gigantesquement (grand)'>,
#  <Cell R8769C6 "indicating 'no' (shake head).">,
#  <Cell R8769C5 "indiquant 'non' (secouer la tête).">,
#  <Cell R8771C6 'completely (tear), badly (torn).'>,
#  <Cell R8771C5 'complètement (déchiré), très mal (déchiré)'>,
#  <Cell R8772C6 'wide (open).'>,
#  <Cell R8772C5 'large (ouvert)'>,
#  <Cell R8774C6 'misshaped and (long) (desc. of ngāl).'>,
#  <Cell R8774C5 'déformé et (long) (desc. de ngāl).'>,
#  <Cell R8775C6 'wide open (mouth).'>,
#  <Cell R8775C5 'grand ouvert (bouche)'>,
#  <Cell R8780C6 'hard (squeeze); carefully (milk).'>,
#  <Cell R8780C5 'dur (presser); soigneusement (lait).'>,
#  <Cell R8782C6 'lightly (land).'>,
#  <Cell R8782C5 'légèrement (terre)'>,
#  <Cell R8785C6 'noisily (take large portions with finger}.'>,
#  <Cell R8785C5 'bruyamment (prendre de grandes portions avec le doigt)'>,
#  <Cell R8786C6 'suddenly (fall).'>,
#  <Cell R8786C5 'soudainement (tomber).'>,
#  <Cell R8787C6 'extremely (strong, sturdy).'>,
#  <Cell R8787C5 'extrêmement (fort, robuste)'>,
#  <Cell R8788C6 'badly (constipated).'>,
#  <Cell R8788C5 'mal (constipé)'>,
#  <Cell R8789C6 'with chopping sound (hit,chop).'>,
#  <Cell R8789C5 'avec un son de coupe (frapper, couper)'>,
#  <Cell R8790C6 'rapidly (swallow).'>,
#  <Cell R8790C5 'rapidement (avaler)'>,
#  <Cell R8792C6 'with a pop (become pierced).'>,
#  <Cell R8792C5 'avec un claquement (devenir percé)'>,
#  <Cell R8794C6 'with force (spear, dig, etc.).'>,
#  <Cell R8794C5 'avec force (lance, creuse, etc.).'>,
#  <Cell R8796C6 'thoroughly (tear, rip, cut through).'>,
#  <Cell R8796C5 'en profondeur (déchirer, déchiqueter, couper à travers)'>,
#  <Cell R8797C6 'dripping out (liquid flow).'>,
#  <Cell R8797C5 'qui goutte (écoulement de liquide)'>,
#  <Cell R8798C6 'thoroughly (squeeze, wring out), etc..'>,
#  <Cell R8798C5 'bien (presser, essorer), etc...'>,
#  <Cell R8799C6 'thoroughly (pierced).'>,
#  <Cell R8799C5 'complètement (percé).'>,
#  <Cell R8801C6 'with a crash (shatter).'>,
#  <Cell R8801C5 'avec un bruit fort (se briser)'>,
#  <Cell R8803C6 'extremely (evil); pitch (black).'>,
#  <Cell R8803C5 'extrêmement (maléfique); noir comme du goudron.'>,
#  <Cell R8806C6 'extremely (bitter).'>,
#  <Cell R8806C5 'extrêmement (amer)'>,
#  <Cell R8809C6 'extremely (thick); be very thick.'>,
#  <Cell R8809C5 'extrêmement (épais) ; être très épais.'>,
#  <Cell R8810C6 'chest [of animal].'>,
#  <Cell R8810C5 "poitrine [d'un animal]">,
#  <Cell R8811C6 'perfectly (ripe).'>,
#  <Cell R8811C5 'parfaitement (mûr).'>,
#  <Cell R8812C6 'area filled with dry reeds (good for hunting in).'>,
#  <Cell R8812C5 'zone remplie de roseaux secs (bon pour la chasse).'>,
#  <Cell R8814C6 'completely (bare,bald).'>,
#  <Cell R8814C5 'complètement (nu, chauve)'>,
#  <Cell R8821C6 'rising up in unison.'>,
#  <Cell R8821C5 "s'élevant à l'unisson">,
#  <Cell R8822C6 'tightly (stuff {in single motion}).'>,
#  <Cell R8822C5 'serré (chose {en un seul mouvement}).'>,
#  <Cell R8824C6 'extremely (rough); be rough.'>,
#  <Cell R8824C5 'extrêmement (rugueux); être rugueux.'>,
#  <Cell R8825C6 'extremely (bitter).'>,
#  <Cell R8825C5 'extrêmement (amer)'>,
#  <Cell R8829C6 'extremely (fat).'>,
#  <Cell R8829C5 'extrêmement (gras)'>,
#  <Cell R8830C6 'with a cracking sound (split).'>,
#  <Cell R8830C5 'avec un bruit de craquement (fendu).'>,
#  <Cell R8832C6 'thick and (long).'>,
#  <Cell R8832C5 'épais et (long).'>,
#  <Cell R8833C6 'suddenly (appear).'>,
#  <Cell R8833C5 'soudainement (apparaître)'>,
#  <Cell R8835C6 'vast and empty.'>,
#  <Cell R8835C5 'vaste et vide.'>,
#  <Cell R8837C6 'perfectly (white) (desc. of ndàa).'>,
#  <Cell R8837C5 'parfaitement (blanc) (desc. de ndàa)'>,
#  <Cell R8838C6 'extremely (deep).'>,
#  <Cell R8838C5 'extrêmement (profond)'>,
#  <Cell R8839C6 'with a rip (tear), badly (torn).'>,
#  <Cell R8839C5 'avec une déchirure (déchiré), mal (déchiré).'>,
#  <Cell R8841C6 'quickly (yawn).'>,
#  <Cell R8841C5 'rapidement (bâillement)'>,
#  <Cell R8844C6 'extremely (cloudy,dirty,thick).'>,
#  <Cell R8844C5 'extrêmement (nuageux, sale, épais)'>,
#  <Cell R8845C6 'the wrong way (go down {liquid}).'>,
#  <Cell R8845C5 'le mauvais sens (descendre {liquide}).'>,
#  <Cell R8849C6 'extremely (twisted,crooked,etc.).'>,
#  <Cell R8849C5 'extrêmement (tordu, courbé, etc.)'>,
#  <Cell R8851C6 'all (white).'>,
#  <Cell R8851C5 'tout (blanc).'>,
#  <Cell R8852C6 'loudly (pop, explode).'>,
#  <Cell R8852C5 'fortement (éclater, exploser).'>,
#  <Cell R8853C6 'energetically (stir [s.t. thick]).'>,
#  <Cell R8853C5 "énergiquement (remuer [qch d'épais]).">,
#  <Cell R8855C6 'in disorder (spread out to dry).'>,
#  <Cell R8855C5 'en désordre (étendu pour sécher)'>,
#  <Cell R8857C6 'perfectly (white).'>,
#  <Cell R8857C5 'parfaitement (blanc)'>,
#  <Cell R8859C6 'terribly (insult) (desc. of ùy).'>,
#  <Cell R8859C5 'terriblement (insulte) (description de ùy)'>,
#  <Cell R8860C6 'very large and flat.'>,
#  <Cell R8860C5 'très grand et plat'>,
#  <Cell R8862C6 'very (long).'>,
#  <Cell R8862C5 'très (long).'>,
#  <Cell R8884C6 'a huge amount (swallow).'>,
#  <Cell R8884C5 'une énorme quantité (avaler)'>,
#  <Cell R8886C6 'brightly (shine).'>,
#  <Cell R8886C5 'brillamment (briller)'>,
#  <Cell R8887C6 'with sobs (cry).'>,
#  <Cell R8887C5 'avec des sanglots (pleurer)'>,
#  <Cell R8888C6 'a lot (itch).'>,
#  <Cell R8888C5 'beaucoup (démangeaison)'>,
#  <Cell R8906C6 'badly (leak).'>,
#  <Cell R8906C5 'mal (fuite)'>,
#  <Cell R8925C6 'extremely (clean); perfectly (clear).'>,
#  <Cell R8925C5 'extrêmement (propre); parfaitement (clair)'>,
#  <Cell R8928C6 'suddenly, quickly (rise, get up).'>,
#  <Cell R8928C5 'soudainement, rapidement (se lever, se lever).'>,
#  <Cell R8929C6 'with an extremely (sharp) point.'>,
#  <Cell R8929C5 'avec une pointe extrêmement (tranchante).'>,
#  <Cell R8930C6 'completely (enter, get in).'>,
#  <Cell R8930C5 'complètement (entrer, rentrer)'>,
#  <Cell R8931C6 'immediately, suddenly (release, let go).'>,
#  <Cell R8931C5 'immédiatement, soudainement (libérer, lâcher)'>,
#  <Cell R8932C6 'wide-mouthed with surprise.'>,
#  <Cell R8932C5 'bouche ouverte de surprise'>,
#  <Cell R8933C6 'cracked (broken).'>,
#  <Cell R8933C5 'craqué (cassé).'>,
#  <Cell R8934C6 'large and hunched (upper back).'>,
#  <Cell R8934C5 'grand et voûté (dos supérieur)'>,
#  <Cell R8935C6 'light (red).'>,
#  <Cell R8935C5 'lumière (rouge).'>,
#  <Cell R8937C6 'badly (sting).'>,
#  <Cell R8937C5 'mal (piquer)'>,
#  <Cell R8938C6 'ugly and very (fat).'>,
#  <Cell R8938C5 'laid et très (gros).'>,
#  <Cell R8939C6 'gently (flow); back and forth (crawl), etc..'>,
#  <Cell R8939C5 'doucement (écoulement); va-et-vient (ramper), etc..'>,
#  <Cell R8940C6 'with force (split); completely (split).'>,
#  <Cell R8940C5 'avec force (diviser) ; complètement (diviser).'>,
#  <Cell R8941C6 'changing position.'>,
#  <Cell R8941C5 'changement de position.'>,
#  <Cell R8942C6 'tearfully (cry).'>,
#  <Cell R8942C5 'en larmes (pleurer).'>,
#  <Cell R8944C6 'carefully (hide).'>,
#  <Cell R8944C5 'soigneusement (cacher)'>,
#  <Cell R8945C6 'quickly (enter).'>,
#  <Cell R8945C5 'rapidement (entrer)'>,
#  <Cell R8946C6 'quickly (enter).'>,
#  <Cell R8946C5 'rapidement (entrer)'>,
#  <Cell R8947C6 'extremely (tall).'>,
#  <Cell R8947C5 'extrêmement (grand).'>,
#  <Cell R8948C6 'completely (soaked).'>,
#  <Cell R8948C5 'complètement (trempé)'>,
#  <Cell R8949C6 'carefully (hide).'>,
#  <Cell R8949C5 'soigneusement (cacher)'>,
#  <Cell R8950C6 'swinging, slowly (open).'>,
#  <Cell R8950C5 'balançant, lentement (ouvert).'>,
#  <Cell R8951C6 'secretly, sneakily.'>,
#  <Cell R8951C5 'secrètement, furtivement'>,
#  <Cell R8952C7 True>,
#  <Cell R8952C8 'could not find in Morkeg'>,
#  <Cell R8953C6 'hard (shake once).'>,
#  <Cell R8953C5 'dur (secouer une fois)'>,
#  <Cell R8955C6 'thin and (tall).'>,
#  <Cell R8955C5 'mince et (grand).'>,
#  <Cell R8956C6 'with a slice (cut).'>,
#  <Cell R8956C5 'avec une tranche (coupée)'>,
#  <Cell R8959C6 'carefully (pour).'>,
#  <Cell R8959C5 'soigneusement (pour).'>,
#  <Cell R8960C6 'stark (naked); extremely (dark), pitch, perfectly (black).'>,
#  <Cell R8960C5 'stark (nu); extrêmement (sombre), pitch, parfaitement (noir).'>,
#  <Cell R8961C6 'wide (open).'>,
#  <Cell R8961C5 'large (ouvert)'>,
#  <Cell R8962C6 'hibiscus [Hibiscus sabdariffa].'>,
#  <Cell R8962C5 'hibiscus [Hibiscus sabdariffa]'>,
#  <Cell R8963C6 'gently (flow); back and forth (crawl), etc..'>,
#  <Cell R8963C5 'doucement (couler); aller-retour (ramper), etc..'>,
#  <Cell R8964C6 'a little bit (take, pinch).'>,
#  <Cell R8964C5 'un peu (prendre, pincement)'>,
#  <Cell R8987C6 'one after another in a straight line.'>,
#  <Cell R8987C5 "un après l'autre en ligne droite.">,
#  <Cell R8991C6 'thoroughly (search).'>,
#  <Cell R8991C5 'rechercher minutieusement'>,
#  <Cell R9002C6 'pleasantly (blow).'>,
#  <Cell R9002C5 'agréablement (souffler)'>,
#  <Cell R9017C6 'refusing to move (remain).'>,
#  <Cell R9017C5 'refuser de bouger (rester)'>,
#  <Cell R9019C6 'hard (fall).'>,
#  <Cell R9019C5 'difficile (chute)'>,
#  <Cell R9025C6 'extremely fat.'>,
#  <Cell R9025C5 'extrêmement gros'>,
#  <Cell R9030C6 'badly (sting).'>,
#  <Cell R9030C5 'mal (piquer)'>,
#  <Cell R9031C6 'unable to move.'>,
#  <Cell R9031C5 'incapable de bouger'>,
#  <Cell R9035C6 'blankly (eyes).'>,
#  <Cell R9035C5 'fixement (yeux)'>,
#  <Cell R9054C6 'vigorously (cook).'>,
#  <Cell R9054C5 'énergiquement (cuisiner).'>,
#  <Cell R9057C6 'completely (untied, loose).'>,
#  <Cell R9057C5 'complètement (détaché, lâche)'>,
#  <Cell R9068C6 'all over (tremble).'>,
#  <Cell R9068C5 'tout autour (trembler)'>,
#  <Cell R9070C6 'extremely (twisted, winding).'>,
#  <Cell R9070C5 'extrêmement (tordu, sinueux)'>,
#  <Cell R9071C6 'plump, round and (fat) {birds}.'>,
#  <Cell R9071C5 'dodu, rond et (gras) {oiseaux}.'>,
#  <Cell R9075C6 'noisily (break {as a gourd}).'>,
#  <Cell R9075C5 'bruyamment (se briser {comme une calebasse})'>,
#  <Cell R9079C6 'completely (cut {s.t. soft}).'>,
#  <Cell R9079C5 'complètement (couper {quelque chose de mou}).'>,
#  <Cell R9084C6 'terrifically (big/fat} (can be desc. of bòo).'>,
#  <Cell R9084C5 'terriblement (grand/gros) (peut être une description de bòo)'>,
#  <Cell R9086C6 'pulling out gummy sauce.'>,
#  <Cell R9086C5 'tirer la sauce gommeuse.'>,
#  <Cell R9087C6 'old thing.'>,
#  <Cell R9087C5 'vieille chose'>,
#  <Cell R9089C6 'very (old).'>,
#  <Cell R9089C5 'très (vieux)'>,
#  <Cell R9091C6 'thud {desc. of pounding when mortar is full}.'>,
#  <Cell R9091C5 'bruit sourd {desc. du pilonnage quand le mortier est plein}.'>,
#  <Cell R9094C6 'lightly (cough).'>,
#  <Cell R9094C5 'légèrement (toux)'>,
#  <Cell R9095C6 'with difficulty (cut).'>,
#  <Cell R9095C5 'avec difficulté (coupé)'>,
#  <Cell R9096C6 'all over (break out in rash) (desc. of tèē).'>,
#  <Cell R9096C5 'partout (éruption cutanée) (description de tèē)'>,
#  <Cell R9098C6 'carefully (fold).'>,
#  <Cell R9098C5 'soigneusement (plié)'>,
#  <Cell R9100C6 'with a sharp noise (break).'>,
#  <Cell R9100C5 'avec un bruit aigu (casser)'>,
#  <Cell R9102C6 'for good, permanently.'>,
#  <Cell R9102C5 'pour de bon, de manière permanente.'>,
#  <Cell R9103C6 'heavily (fall [s.t. long or tall]).'>,
#  <Cell R9103C5 'lourdement (tomber [qch de long ou de haut]).'>,
#  <Cell R9108C6 'with a cracking noise (sparkle,etc.)'>,
#  <Cell R9108C5 'avec un bruit de craquement (étincelle, etc.)'>,
#  <Cell R9110C6 'completely (tear up, tear).'>,
#  <Cell R9110C5 'complètement (déchirer)'>,
#  <Cell R9111C6 'with a loud slurp (sip, drink).'>,
#  <Cell R9111C5 'avec un bruit de succion fort (boire, boisson).'>,
#  <Cell R9112C6 'suddenly (get up, rise).'>,
#  <Cell R9112C5 'soudainement (se lever, se lever)'>,
#  <Cell R9114C6 'hard, with a tug (pull).'>,
#  <Cell R9114C5 'dur, avec une traction (tirer)'>,
#  <Cell R9116C6 'with a crunching sound (crush; chew).'>,
#  <Cell R9116C5 'avec un bruit de craquement (écraser ; mâcher)'>,
#  <Cell R9118C6 'be fat and soft and bouncy.'>,
#  <Cell R9118C5 'être gros, doux et rebondissant.'>,
#  <Cell R9119C6 'suddenly (start running).'>,
#  <Cell R9119C5 'soudainement (commencer à courir)'>,
#  <Cell R9120C6 'loudly (crackle).'>,
#  <Cell R9120C5 'fortement (craquement).'>,
#  <Cell R9121C6 'be pug-nosed.'>,
#  <Cell R9121C5 'avoir le nez retroussé'>,
#  <Cell R9122C6 'hard (hit,whip {as with branch whip}).'>,
#  <Cell R9122C5 'dur (frapper, fouetter {comme avec un fouet de branche}).'>,
#  <Cell R9123C6 'with a slurp (sip [s.t. hot]).'>,
#  <Cell R9123C5 'avec un bruit de succion (boire [qch de chaud]).'>,
#  <Cell R9127C6 'unimportant (plural: ríw-ríw).'>,
#  <Cell R9127C5 'sans importance (pluriel: ríw-ríw)'>,
#  <Cell R9129C6 'hard (hit with s.t.)'>,
#  <Cell R9129C5 'dur (frapper avec qch)'>,
#  <Cell R9130C6 'badly (bite).'>,
#  <Cell R9130C5 'mal (mordre)'>,
#  <Cell R9131C6 'completely (red).'>,
#  <Cell R9131C5 'complètement (rouge)'>,
#  <Cell R9132C6 'energetically (roll about).'>,
#  <Cell R9132C5 'énergiquement (rouler)'>,
#  <Cell R9134C6 'extremely (wide).'>,
#  <Cell R9134C5 'extrêmement (large)'>,
#  <Cell R9137C6 'with a crack (break {wood or s.t. wooden}).'>,
#  <Cell R9137C5 'avec une fissure (casser {bois ou qqch en bois}).'>,
#  <Cell R9139C6 'very light {ant: heavy} (emphatic form à-à).'>,
#  <Cell R9139C5 'très léger {ant: lourd} (forme emphatique à-à).'>,
#  <Cell R9140C6 'flapping up and down; bobbing up and down.'>,
#  <Cell R9140C5 'flottement vers le haut et vers le bas; qui monte et descend en ondulant.'>,
#  <Cell R9141C6 'with a slap (hit).'>,
#  <Cell R9141C5 'avec une claque (coup).'>,
#  <Cell R9144C6 "with bubbles in water (in expression ɓà à 'make bubbles {in water}'; see also ɓà à).">,
#  <Cell R9144C5 "avec des bulles dans l'eau (dans l'expression ɓà à 'faire des bulles {dans l'eau}'; voir aussi ɓà à).">,
#  <Cell R9146C6 'with lots of small spots (be spotted).'>,
#  <Cell R9146C5 'avec beaucoup de petites taches (être tacheté)'>,
#  <Cell R9147C6 'suddenly (appear, come upon).'>,
#  <Cell R9147C5 'soudainement (apparaître, se produire)'>,
#  <Cell R9148C6 'suddenly (arrive).'>,
#  <Cell R9148C5 'soudainement (arriver)'>,
#  <Cell R9149C6 'loudly (yell at; roar).'>,
#  <Cell R9149C5 'fortement (crier sur; rugir).'>,
#  <Cell R9151C6 'loudly (blow nose).'>,
#  <Cell R9151C5 'fortement (se moucher)'>,
#  <Cell R9152C6 'extremely (muddy, cloudy, etc.).'>,
#  <Cell R9152C5 'extrêmement (boueux, nuageux, etc.)'>,
#  <Cell R9154C6 'in a foam (rise up).'>,
#  <Cell R9154C5 "dans une mousse (s'élever)">,
#  <Cell R9156C6 'extremely (tall).'>,
#  <Cell R9156C5 'extrêmement (grand)'>,
#  <Cell R9157C6 'in a foam (one time) (rise up).'>,
#  <Cell R9157C5 'dans une mousse (une fois) (se lever).'>,
#  <Cell R9158C6 'extremely (wide).'>,
#  <Cell R9158C5 'extrêmement (vaste)'>,
#  <Cell R9159C6 'shooting by (pass).'>,
#  <Cell R9159C5 'tir par (pass).'>,
#  <Cell R9161C6 'bright (red).'>,
#  <Cell R9161C5 'rouge vif'>,
#  <Cell R9162C6 'pure.'>,
#  <Cell R9162C5 'pur'>,
#  <Cell R9163C6 'tightly (tie).'>,
#  <Cell R9163C5 'serrer (attacher) étroitement'>,
#  <Cell R9164C6 'back and forth (fan fire).'>,
#  <Cell R9164C5 'en avant et en arrière (ventiler le feu)'>,
#  <Cell R9165C6 'extremely (thick).'>,
#  <Cell R9165C5 'extrêmement (épais).'>,
#  <Cell R9166C6 'loudly; with a snort (breathe).'>,
#  <Cell R9166C5 'fortement ; avec un reniflement (respirer).'>,
#  <Cell R9167C6 'rapidly (come out, go out; pass).'>,
#  <Cell R9167C5 'rapidement (sortir, partir rapidement; passer)'>,
#  <Cell R9168C6 'dark (red), reddish.'>,
#  <Cell R9168C5 'sombre (rouge), rougeâtre'>,
#  <Cell R9169C6 'thin and (tall).'>,
#  <Cell R9169C5 'mince et (grand).'>,
#  <Cell R9170C6 'neatly (spit).'>,
#  <Cell R9170C5 'soigneusement (cracher).'>,
#  <Cell R9172C6 'time.'>,
#  <Cell R9172C5 'temps'>,
#  <Cell R9173C6 'with a spring (jump).'>,
#  <Cell R9173C5 'Hello'>,
#  <Cell R9174C6 'thoroughly (glue,spread).'>,
#  <Cell R9174C5 'en profondeur (colle, étaler)'>,
#  <Cell R9175C6 'with a hissing sound (pass gas).'>,
#  <Cell R9175C5 'avec un son sifflant (lâcher un pet)'>,
#  <Cell R9176C6 'with a hissing sound (pass gas).'>,
#  <Cell R9176C5 'avec un son sifflant (lâcher un pet).'>,
#  <Cell R9177C6 'firmly (grab,seize).'>,
#  <Cell R9177C5 'fermement (attraper, saisir)'>,
#  <Cell R9178C6 'tensely (contract body).'>,
#  <Cell R9178C5 'tendu (contraction du corps)'>,
#  <Cell R9179C6 'squirting out.'>,
#  <Cell R9179C5 'éjaculation'>,
#  <Cell R9181C6 'quickly (closing eyelids).'>,
#  <Cell R9181C5 'fermer rapidement les paupières'>,
#  <Cell R9185C6 'quickly, suddenly (rise) (desc. of ɓày).'>,
#  <Cell R9185C5 'rapidement, soudainement (augmenter) (desc. de ɓày).'>,
#  <Cell R9186C6 'enormously (swell up).'>,
#  <Cell R9186C5 'énormément (gonfler).'>,
#  <Cell R9191C6 'hard (scratch, pinch), etc..'>,
#  <Cell R9191C5 'dur (gratter, pincer), etc.'>,
#  <Cell R9192C6 'suddenly (turn).'>,
#  <Cell R9192C5 'soudainement (tourner).'>,
#  <Cell R9193C6 'slowly, carefully (walk).'>,
#  <Cell R9193C5 'lentement, prudemment (marcher).'>,
#  <Cell R9195C6 'perfectly (straight).'>,
#  <Cell R9195C5 'parfaitement (droit)'>,
#  <Cell R9196C6 'completely (split, broken up).'>,
#  <Cell R9196C5 'complètement (divisé, cassé)'>,
#  <Cell R9198C6 'in dignified fashion (walk).'>,
#  <Cell R9198C5 "d'une manière digne (marche)">,
#  <Cell R9199C6 'suddenly, in a leap (get up).'>,
#  <Cell R9199C5 "soudainement, d'un bond (se lever)">,
#  <Cell R9200C6 'abruptly (leave).'>,
#  <Cell R9200C5 'quitter brusquement'>,
#  <Cell R9201C6 'badly (affected by need).'>,
#  <Cell R9201C5 'gravement (affecté par le besoin)'>,
#  <Cell R9202C6 'in a disgusting fashion (spit).'>,
#  <Cell R9202C5 'de manière dégoûtante (cracher)'>,
#  <Cell R9203C6 'perfectly (smooth).'>,
#  <Cell R9203C5 'parfaitement (lisse)'>,
#  <Cell R9204C6 'with smoke coming out.'>,
#  <Cell R9204C5 'avec de la fumée qui sort.'>,
#  <Cell R9206C6 'firmly (grab).'>,
#  <Cell R9206C5 'fermement (saisir)'>,
#  <Cell R9209C6 'completely (split).'>,
#  <Cell R9209C5 'complètement (divisé).'>,
#  <Cell R9211C6 'quite (short) {indicates about 1 foot}.'>,
#  <Cell R9211C5 'assez (court) {indique environ 1 pied}'>,
#  <Cell R9212C6 'hard (fall).'>,
#  <Cell R9212C5 'dur (tomber)'>,
#  <Cell R9221C6 'drop by drop (fall {liquid}).'>,
#  <Cell R9221C5 'goutte à goutte (tomber {liquide})'>,
#  <Cell R9223C6 'with a drip (fall {water}).'>,
#  <Cell R9223C5 'avec un goutte-à-goutte (chute {eau}).'>,
#  <Cell R9225C6 "to indicate 'no' (shake head).">,
#  <Cell R9225C5 "pour indiquer 'non' (secouer la tête).">,
#  <Cell R9226C6 'right off (cut).'>,
#  <Cell R9226C5 'tout de suite (couper)'>,
#  <Cell R9227C6 'with a crack (break {wood or s.t. wooden}).'>,
#  <Cell R9227C5 'avec une fissure (casser {bois ou qqch en bois}).'>,
#  <Cell R9228C6 'firmly (tie, attach).'>,
#  <Cell R9228C5 'fermement (attacher, fixer)'>,
#  <Cell R9229C6 'extremely (cold, cool).'>,
#  <Cell R9229C5 'extrêmement (froid, frais).'>,
#  <Cell R9230C6 'much (too big for).'>,
#  <Cell R9230C5 'beaucoup (trop grand pour)'>,
#  <Cell R9231C6 'slightly (hot).'>,
#  <Cell R9231C5 'légèrement (chaud)'>,
#  <Cell R9232C6 'with a bang (explode, go off).'>,
#  <Cell R9232C5 'avec un bang (exploser, se déclencher)'>,
#  <Cell R9236C6 'extremely (tall).'>,
#  <Cell R9236C5 'extrêmement (grand)'>,
#  <Cell R9237C6 'with a snap (cut through).'>,
#  <Cell R9237C5 'avec un claquement (couper à travers)'>,
#  <Cell R9238C6 'quickly (closing eyelids).'>,
#  <Cell R9238C5 'rapidement (fermeture des paupières).'>,
#  <Cell R9239C6 'worried.'>,
#  <Cell R9239C5 'inquiet'>,
#  <Cell R9240C6 'completely (dry up).'>,
#  <Cell R9240C5 'complètement (sécher)'>,
#  <Cell R9241C6 'perfectly (dry, clear).'>,
#  <Cell R9241C5 'parfaitement (sec, clair)'>,
#  <Cell R9242C6 'squirting out, in squirts.'>,
#  <Cell R9242C5 'éclabousser, en éclaboussures.'>,
#  <Cell R9243C6 'very (short),cut off.'>,
#  <Cell R9243C5 'très (court), coupé'>,
#  <Cell R9244C6 'badly, a lot (swell, rise up).'>,
#  <Cell R9244C5 'mal, beaucoup (gonfler, se lever).'>,
#  <Cell R9246C6 'in a skin rash (break out).'>,
#  <Cell R9246C5 'dans une éruption cutanée (éclater)'>,
#  <Cell R9247C6 'all over, about (scatter).'>,
#  <Cell R9247C5 'partout, à propos (éparpiller)'>,
#  <Cell R9249C6 'badly (crush).'>,
#  <Cell R9249C5 'mal (écraser).'>,
#  <Cell R9250C6 'perfectly straight.'>,
#  <Cell R9250C5 'parfaitement droit'>,
#  <Cell R9253C6 'in a lump, without moving (fall).'>,
#  <Cell R9253C5 'en un morceau, sans bouger (tomber)'>,
#  <Cell R9254C6 'completely (broken/cut through).'>,
#  <Cell R9254C5 'complètement (brisé/coupé à travers)'>,
#  <Cell R9256C6 'perfectly (straight).'>,
#  <Cell R9256C5 'parfaitement (droit)'>,
#  <Cell R10189C6 'right (down {sit}).'>,
#  <Cell R10189C5 "droit (vers le bas {s'asseoir}).">,
#  <Cell R10190C6 'extremely short.'>,
#  <Cell R10190C5 'extrêmement court'>,
#  <Cell R10191C6 'fine (powder); heavily (pour down [powder]).'>,
#  <Cell R10191C5 'fine (poudre); fortement (verser [de la poudre])'>,
#  <Cell R10194C6 'never, not at all.'>,
#  <Cell R10194C5 'jamais, pas du tout'>,
#  <Cell R10195C6 'a handful (take with fingers).'>,
#  <Cell R10195C5 'une poignée (prendre avec les doigts)'>,
#  <Cell R10207C6 'useless, stupid (chatter).'>,
#  <Cell R10207C5 'inutile, stupide (bavardage)'>,
#  <Cell R10212C6 'loudly (cry, laugh).'>,
#  <Cell R10212C5 'fortement (cri, rire)'>,
#  <Cell R10350C6 'with loud boom; bang (make noise).'>,
#  <Cell R10350C5 'avec un grand boum; bang (faire du bruit)'>]

# %%
sheet.update_cells(cells)
# Out:
# {'spreadsheetId': '1KbpQS0RdcLhUOJNFNdXlnTDZBKEU2S8Q7DnJhPYrr2M',
#  'updatedRange': "'mbay-translations-review'!E8527:H10350",
#  'updatedRows': 349,
#  'updatedColumns': 4,
#  'updatedCells': 698}

# %%
import openai

openai.api_key = os.environ["OPENAI_API_KEY"]


def translate_en_to_fr_with_context(input_text: str, context: str) -> str:
    if context:
        context = f"\nContext: {context}"
    prompt = f"""
Translate from English to French.{context}
English: {input_text}
French:"""
    response = openai.ChatCompletion.create(
        model="gpt-4", messages=[{"role": "user", "content": prompt}]
    )
    return response.choices[0].message.content


def fix_failed_translation(cells: list[Cell], record: dict[str, str], row_id: int):
    print(f"Row {row_id} is English, {record['french']} | {record['english']}")
    user_input = input("Do you want to continue with the fix? (yes/no/quit): ")
    match user_input.lower():
        case "yes" | "y":
            while True:
                context = input("Please provide extra context to guide the AI: ")
                translated_text = translate_en_to_fr_with_context(
                    record["english"], context
                )
                resp = input(
                    f"result: {translated_text}.\n[a]ccept / [r]etry / [p]ass?"
                )
                match resp.lower():
                    case "a":
                        break
                    case "r":
                        continue
                    case _:
                        return True

            cells.append(Cell(row_id, columns["french"], translated_text))
            return True
        case "no" | "n":
            return True
        case "quit" | "q":
            return False

# %%
translate_en_to_fr_with_context("hide, skin", "this is about animal skin")
# Out:
# 'peau, fourrure'

# %%
# Get all records of the data
records = sheet.get_all_records()
cells = []
# Iterate over the rows
for row_id, record in enumerate(records, start=2):
    if detect(record["french"]) == "en":
        next = fix_failed_translation(cells, record, row_id)
        if not next:
            break
# Out:
# Row 137 is English, tisserand ou gros-bec | weaver or grosbeak.
# Row 200 is English, Je cherche mon stylo. | I am looking for my pen.
# Row 350 is English, chaton {informel} | kitty cat {informal}
# Row 364 is English, fourmilier {grand pangolin terrestre} | anteater {giant ground pangolin}
# Row 369 is English, patch [of cloth] | patch [of cloth]
# Row 404 is English, type of snail, shell used in gambling game | type of snail, shell used in gambling game
# Row 471 is English, milk; wring out; etc. | milk; wring out; etc.
# Row 511 is English, chasse collective | collective hunt
# Row 565 is English, lover of hunting/fighting/fishing | lover of hunting/fighting/fishing
# Row 570 is English, infirme | cripple
# Row 626 is English, bale of animal feed {grasses and leaves dried and tied}; fodder | bale of animal feed {grasses and leaves dried and tied}; fodder
# Row 749 is English, bec | beak
# Row 783 is English, twig wilter bug {bug with oddly shaped legs, which suck sap from plants} | twig wilter bug {bug with oddly shaped legs, which suck sap from plants}
# Row 810 is English, idiot, fool | idiot, fool
# Row 832 is English, cleanliness | cleanliness, clearness, brightness
# Row 994 is English, infirme | cripple
# Row 996 is English, to shout | public crier
# Row 1000 is English, Christian {lit: one who has promised} | Christian {lit: one who has promised}
# Row 1006 is English, gossip, person who gossips | gossip, person who gossips
# Row 1081 is English, cacher, peau | hide, skin
# Row 1142 is English, boucher | butcher
# Row 1164 is English, thorn bush; tree [Acacia ataxacantha] and [Acacia macrostachya] | thorn bush; tree [Acacia ataxacantha] and [Acacia macrostachya]
# Row 1176 is English, type of mildly bitter cassava of Central African origin; no longer commonly grown | type of mildly bitter cassava of Central African origin; no longer commonly grown
# Row 1193 is English, caterpillar with hair {inedible and destructive} | caterpillar with hair {inedible and destructive}
# Row 1241 is English, cousin maternel | maternal cousin
# Row 1319 is English, cacher, peau | hide, skin
# Row 1346 is English, front | forehead
# Row 1368 is English, pull up; scorch; etc. | pull up; scorch; etc.
# Row 1374 is English, suck | suck, eat [juicy fruit, sauce]
# Row 1401 is English, type of small black centipede, bite even more painful that that of normal centipede | type of small black centipede, bite even more painful that that of normal centipede
# Row 1403 is English, spell and fetishes related to hunting and fishing | spell and fetishes related to hunting and fishing
# Row 1453 is English, achat, acheter | purchase, buy
# Row 1479 is English, Je cherche attentivement mon stylo perdu. | I'm searching carefully for my lost pen.
# Row 1532 is English, barbed fish spear or harpoon | barbed fish spear or harpoon
# Row 1617 is English, beer house, local bar | beer house, local bar
# Row 1717 is English, refus; refuser | refusal; refusing
# Row 1739 is English, stare at, give [s.o.] dirty look | stare at, give [s.o.] dirty look
# Row 1796 is English, poisson-chat [Synodontis schall, Hemisynodontis membranaceus] | catfish [Synodontis schall, Hemisynodontis membranaceus]
# Row 1800 is English, stare at, give [s.o.] dirty look | stare at, give [s.o.] dirty look
# Row 1804 is English, grasshopper, locust (very large, edible) | grasshopper, locust (very large, edible)
# Row 1839 is English, Fifty (250 CFA) and I bought myself some shoes with it. | Fifty (250 CFA) and I bought myself some shoes with it.
# Row 1871 is English, The spell for protecting a field {against theft} is crossed sticks. | The spell for protecting a field {against theft} is crossed sticks.
# Row 1881 is English, The fruit bat is a small bird that just eats mangoes. People eat it. It tastes good. It does not have a lot of meat, it is very bony. | The fruit bat is a small bird that just eats mangoes.  People eat it.  It tastes good.  It does not have a lot of meat, it is very bony.
# Row 1914 is English, sleep around; live debauched life | sleep around; live debauched life
# Row 1936 is English, bicyclette | bicycle
# Row 1950 is English, chat | cat
# Row 1963 is English, plate | plate, dish, bowl
# Row 2017 is English, fourche d'arbre | fork of tree
# Row 2037 is English, foule | crowd
# Row 2095 is English, coton [Gossypium sp.] | cotton [Gossypium sp.]
# Row 2110 is English, boucher | assistant to butcher
# Row 2141 is English, iguane, grand lézard terrestre [Varanus exanthematicus] | iguana, large land lizard [Varanus exanthematicus]
# Row 2253 is English, omoplate | shoulder blade
# Row 2267 is English, pêche collective | collective fishing
# Row 2300 is English, Wow! Regardez comment ce cheval court! | Wow!  Look how that horse is running!
# Row 2378 is English, mousetrap | mousetrap
# Row 2399 is English, pied crow [Corvus albus] | pied crow [Corvus albus]
# Row 2459 is English, The house lizard is similar to the yard lizard but its exterior is shiny. It lies next to water pots because it loves cool places. People say that if you kill them often you'll have no strength. | The house lizard is similar to the yard lizard but its exterior is shiny.  It lies next to water pots because it loves cool places.  People say that if you kill them often you'll have no strength.
# Row 2537 is English, The tuber of this plant is similar to that of the finger potato but the former is round and has a red exterior. | The tuber of this plant is similar to that of the finger potato but the former is round and has a red exterior.
# Row 2588 is English, bachelor | bachelor, unmarried woman
# Row 2600 is English, place across, set across | place across, set across
# Row 2620 is English, A grasshopper is an insect that eats grass leaves; some of them are eaten by people. | A grasshopper is an insect that eats grass leaves; some of them are eaten by people.
# Row 2713 is English, marchandise | merchandise
# Row 2766 is English, The small river frog lives in ponds or in grass. People eat it. Its body is red. | The small river frog lives in ponds or in grass.  People eat it.  Its body is red.
# Row 2842 is English, type of broom made of branches {used to sweep ground of compounds} | type of broom made of branches {used to sweep ground of compounds}
# Row 2866 is English, chameau | camel
# Row 2870 is English, boucher | butcher
# Row 2874 is English, orphelin | orphan
# Row 2897 is English, force | force
# Row 2899 is English, dent; crash in | dent; crash in
# Row 2923 is English, hearthstone | hearthstone
# Row 2993 is English, marchandise | merchandise
# Row 2998 is English, relâcher | make loose
# Row 3020 is English, rites, fetishes, traditions | rites, fetishes, traditions
# Row 3025 is English, type of large grey house rat which has invaded Mbay area from Central Africa | type of large grey house rat which has invaded Mbay area from Central Africa
# Row 3082 is English, male name {with twins, either preceding a second male twin (Ngābà/Kōrōó), or following female twin (Ngābà/Kōrōó)} | male name {with twins, either preceding a second male twin (Ngābà/Kōrōó), or following female twin (Ngābà/Kōrōó)}
# Row 3083 is English, thank you | thank you; thank goodness; enjoy your food
# Row 3087 is English, anguille [Gymnarchus niloticus] | eel [Gymnarchus niloticus]
# Row 3128 is English, vigorously (boil) {with substance churning in a liquid} | vigorously (boil) {with substance churning in a liquid}
# Row 3130 is English, breast of goat {considered most delicious portion} | breast of goat {considered most delicious portion}
# Row 3133 is English, string of net laced through bottom of fishing net between two poles at sides | string of net laced through bottom of fishing net between two poles at sides
# Row 3139 is English, lovely young woman {lit: the center of loveliness} | lovely young woman {lit: the center of loveliness}
# Row 3168 is English, pied crow [Corvus albus] | pied crow [Corvus albus]
# Row 3198 is English, orphelin | orphan
# Row 3381 is English, rester immobile, ne pas bouger | [s.o.] to stay put, not move around
# Row 3385 is English, Un camion fait 'honk-honk'. | A truck goes 'honk-honk'.
# Row 3439 is English, room in back {away from door} | room in back {away from door}
# Row 3465 is English, bosse | lump
# Row 3467 is English, lump of sugar | lump of sugar/rock salt/porridge/tapioca
# Row 3474 is English, beaucoup souffrir | suffer a lot
# Row 3490 is English, mushiness, wet flesh [of certain fruits] | mushiness, wet flesh [of certain fruits]
# Row 3512 is English, force, strength | force, strength
# Row 3543 is English, The chief was the very first one to have his cotton weighed. | The chief was the very first one to have his cotton weighed.
# Row 3558 is English, bouche {comme insulte} | mouth {as insult}
# Row 3571 is English, Bean balls are crushed beans wrapped in a leaf. | Bean balls are crushed beans wrapped in a leaf.
# Row 3574 is English, blouse | blouse
# Row 3612 is English, jerking about; darting; waddling back and forth | jerking about; darting; waddling back and forth
# Row 3613 is English, jerking about, waddling back and forth | jerking about, waddling back and forth
# Row 3621 is English, incliner, pencher | tilt, lean
# Row 3671 is English, bicyclette | bicycle
# Row 3676 is English, importance, important one or thing | importance, important one or thing
# Row 3862 is English, People call the whip made out of 'gum' branches 'Borbonde'. | People call the whip made out of 'gum' branches 'Borbonde'.
# Row 3872 is English, manioc [lit: yam of cotton tree] | manioc [lit: yam of cotton tree]
# Row 3887 is English, skinny old worn out breasts {slang} | skinny old worn out breasts {slang}
# Row 3903 is English, sunglasses {lit: stare at your mother-in-law} | sunglasses {lit: stare at your mother-in-law}
# Row 4015 is English, type d'infection urinaire | type of urinary infection
# Row 4084 is English, hangnails; ingrown toenail; any sore around nails | hangnails; ingrown toenail; any sore around nails
# Row 4194 is English, manger [qch] cru | eat [s.t. raw]
# Row 4198 is English, sticking up and dirty (hair) | sticking up and dirty (hair)
# Row 4230 is English, ganglion, infection in one part of body caused by wound in nearby area | ganglion, infection in one part of body caused by wound in nearby area
# Row 4248 is English, troublemaker {lit: I saw I told them} | troublemaker {lit: I saw I told them}
# Row 4257 is English, female cricket | female cricket
# Row 4268 is English, offre, offrir | offer, offer to give
# Row 4274 is English, common waterbuck, defassa [Kobus ellipsiprymnus] | common waterbuck, defassa [Kobus ellipsiprymnus]
# Row 4284 is English, rechercher attentivement | search carefully for
# Row 4307 is English, type of charm ('gri-gri'), normally kept in small leather pouch and worn on string around neck | type of charm ('gri-gri'), normally kept in small leather pouch and worn on string around neck
# Row 4368 is English, chacal {grand} | jackal {large}
# Row 4387 is English, chapeau | hat
# Row 4426 is English, type of edible caterpillar, considered especially tasty | type of edible caterpillar, considered especially tasty
# Row 4427 is English, type of edible hairless caterpillar found on njúwá tree | type of edible hairless caterpillar found on njúwá tree
# Row 4529 is English, trunk, suitcase {for carrying or storing clothes} | trunk, suitcase {for carrying or storing clothes}
# Row 4538 is English, chasser {fig.} | chase away {fig.}
# Row 4611 is English, bushbuck [Tragelaphus scriptus] | bushbuck [Tragelaphus scriptus]
# Row 4669 is English, intestins | intestines
# Row 4728 is English, marchand | merchant
# Row 4757 is English, char, burn; be charred, burned | char, burn; be charred, burned
# Row 4790 is English, chanter | sing
# Row 4799 is English, tongs, sandales en caoutchouc | thongs, rubber sandals
# Row 4816 is English, fine mat that can be rolled up {woven in north and sold by Muslim merchants} | fine mat that can be rolled up {woven in north and sold by Muslim merchants}
# Row 4825 is English, throne, chair [for chief] | throne, chair [for chief]
# Row 4847 is English, village, town; home | village, town; home
# Row 4860 is English, type of poisonous snake {cobra, 'spitting' snake} | type of poisonous snake {cobra, 'spitting' snake}
# Row 4920 is English, tongs {of blacksmith} | tongs {of blacksmith}
# Row 4939 is English, pound [grain] {to remove husk or chaff} | pound [grain] {to remove husk or chaff}
# Row 4959 is English, type de grand bassin | type of large basin
# Row 5070 is English, Chad | Chad
# Row 5084 is English, force | strength
# Row 5140 is English, type of small drum consisting of two small drums attached together | type of small drum consisting of two small drums attached together
# Row 5143 is English, type d'herbe [Hyparrhenia bagirmica] | type of grass [Hyparrhenia bagirmica]
# Row 5186 is English, jack (cards) | jack (cards)
# Row 5187 is English, jack of spades/hearts/diamonds/clubs | jack of spades/hearts/diamonds/clubs
# Row 5190 is English, The woman gathered a pile of leaf ashes and poured water on it in order to make salt. | The woman gathered a pile of leaf ashes and poured water on it in order to make salt.
# Row 5222 is English, stalk of peanut | stalk of peanut
# Row 5276 is English, cove, section of river, bend | cove, section of river, bend
# Row 5311 is English, small undeveloped tree/mushroom/cotton plant | small undeveloped tree/mushroom/cotton plant
# Row 5369 is English, 'Goylo' sauce is made of beans cooked with flour while 'guwse' is beans cooked in 'long sauce'. | 'Goylo' sauce is made of beans cooked with flour while 'guwse' is beans cooked in 'long sauce'.
# Row 5370 is English, rum-a-tum-tum {sound of drum} | rum-a-tum-tum {sound of drum}
# Row 5408 is English, coton-tige | cotton bud
# Row 5516 is English, cracher | spit
# Row 5559 is English, cane rat [Thryonomys swinderianus] | cane rat [Thryonomys swinderianus]
# Row 5578 is English, sweat | sweat
# Row 5616 is English, A spell is something used by people to protect their fields. | A spell is something used by people to protect their fields.
# Row 5660 is English, snare made from hair of animal tail | snare made from hair of animal tail
# Row 5714 is English, syphilis | syphilis
# Row 5753 is English, secouer, bouger | shake, move
# Row 5770 is English, rechercher attentivement, parcourir | search carefully, go through
# Row 5874 is English, thermos | thermos
# Row 5894 is English, short vest {worn by horsemen or by city dwellers} | short vest {worn by horsemen or by city dwellers}
# Row 5898 is English, accoucher | giving birth
# Row 5905 is English, chemise, blouse | shirt, blouse
# Row 5997 is English, type de casserole | type of cooking pot
# Row 6035 is English, Mercredi | Wednesday
# Row 6036 is English, Mercredi | Wednesday
# Row 6055 is English, Octobre | October
# Row 6065 is English, cacher, garder secret | hide, keep secret
# Row 6080 is English, pass without entering [trap] | pass without entering [trap]
# Row 6089 is English, hearts {suit in cards} | hearts {suit in cards}
# Row 6096 is English, clubs {suit in cards} | clubs {suit in cards}
# Row 6155 is English, type de poisson-chat [Chrysichthys auratus] | type of catfish [Chrysichthys auratus]
# Row 6156 is English, type de poisson-chat [Auchenoglanis biscutatus] | type of catfish [Auchenoglanis biscutatus]
# Row 6159 is English, type de poisson-chat [Bagrus bayad] | type of catfish [Bagrus bayad]
# Row 6161 is English, red flanked duiker [Cephalophus rufilatus] | red flanked duiker [Cephalophus rufilatus]
# Row 6179 is English, roan antelope [Hippotragus equinus] | roan antelope [Hippotragus equinus]
# Row 6201 is English, common or grey duiker [Cephalophus grimmia] | common or grey duiker [Cephalophus grimmia]
# Row 6203 is English, {Proverb}  If you didn't catch a duiker, did you cut the rope?  {Don't count your chickens before the eggs are hatched.} | {Proverb}  If you didn't catch a duiker, did you cut the rope?  {Don't count your chickens before the eggs are hatched.}
# Row 6291 is English, force, strength | force, strength
# Row 6338 is English, argent; payer | money; pay
# Row 6362 is English, dragon fly {which appears in dry season} | dragon fly {which appears in dry season}
# Row 6370 is English, The woman broke up the termite hill to make hearthstones. | The woman broke up the termite hill to make hearthstones.
# Row 6378 is English, gleaning; freeloading | gleaning; freeloading
# Row 6411 is English, divorce [husband] | divorce [husband]
# Row 6459 is English, He saved his money until he had seven hundred seventy-seven thousand, seven hundred and seventy-seven. | He saved his money until he had seven hundred seventy-seven thousand, seven hundred and seventy-seven.
# Row 6528 is English, cracher | spit
# Row 6534 is English, then {indicates preceding clause occurs prior to following clause: normally followed by lā...yé clause} | then {indicates preceding clause occurs prior to following clause: normally followed by lā...yé clause}
# Row 6644 is English, cluck cluck {cry of hen} | cluck cluck {cry of hen}
# Row 6660 is English, female name {often given to second born twin, first of whom is male <named Ngāró>} | female name {often given to second born twin, first of whom is male <named Ngāró>}
# Row 6675 is English, Kotoko {people inhabiting river areas near Ndjamena} | Kotoko {people inhabiting river areas near Ndjamena}
# Row 6719 is English, officier militaire | military officer
# Row 6754 is English, bouton | button
# Row 6801 is English, cap of bottle {normally beer} | cap of bottle {normally beer}
# Row 6835 is English, type d'arbre [Strychnos sp.] | type of tree [Strychnos sp.]
# Row 6874 is English, This tree is used to make rope for roofs as well as for weaving grass fencing. | This tree is used to make rope for roofs as well as for weaving grass fencing.
# Row 6880 is English, People eat the fruit of this bush. Goats eat its leaf, people eat its fruit. | People eat the fruit of this bush.   Goats eat its leaf, people eat its fruit.
# Row 6885 is English, type d'herbe [Imperata cylindrica] | type of grass [Imperata cylindrica]
# Row 6893 is English, type of large tree [Daniellia oliveri] | type of large tree [Daniellia oliveri]
# Row 6900 is English, type d'arbre {probablement [Canarium schweinfurthii]} | type of tree {probably [Canarium schweinfurthii]}
# Row 6904 is English, type d'herbe [Eleusine indica] | type of grass [Eleusine indica]
# Row 6958 is English, bosse [vache, chameau] | hump [cow, camel]
# Row 6965 is English, club {for fishing} | club {for fishing}
# Row 7014 is English, The sleeveless shirt is a shirt for horse-riders. | The sleeveless shirt is a shirt for horse-riders.
# Row 7024 is English, cotton tree {normally called kapok tree} [Ceiba pentandra] | cotton tree {normally called kapok tree} [Ceiba pentandra]
# Row 7031 is English, type d'arbre [Jatropha sp.] | type of tree [Jatropha sp.]
# Row 7033 is English, type de buisson [Securidaca longepedunculata] | type of bush [Securidaca longepedunculata]
# Row 7035 is English, type d'herbe | type of grass
# Row 7066 is English, This plant is used to make grass fencing. Its leaves are crushed in water to make it tangy for drinking. | This plant is used to make grass fencing.  Its leaves are crushed in water to make it tangy for drinking.
# Row 7067 is English, type d'herbe [Sansevieria liberica] | type of grass [Sansevieria liberica]
# Row 7081 is English, type d'herbe | type of grass
# Row 7083 is English, type d'arbre [Amblygonocarpus andongensis] | type of tree [Amblygonocarpus andongensis]
# Row 7100 is English, type de palmier [Borassus aethiopum] | type of palm tree [Borassus aethiopum]
# Row 7113 is English, type of tall grass, used in making grass fencing [Cymbopogon giganteus] | type of tall grass, used in making grass fencing [Cymbopogon giganteus]
# Row 7140 is English, type de buisson [Crotalaria sp.] | type of bush [Crotalaria sp.]
# Row 7194 is English, dum palm tree [Hyphaene thebaica] | dum palm tree [Hyphaene thebaica]
# Row 7207 is English, type d'arbre [Sclerocarya birrea] | type of tree [Sclerocarya birrea]
# Row 7236 is English, type d'herbe | type of grass
# Row 7330 is English, type d'insecte | type of insect
# Row 7353 is English, pound, grind [grain] {to remove the bran; done with a little water} | pound, grind [grain] {to remove the bran; done with a little water}
# Row 7418 is English, ramasser [s.t.], soulever [s.t.] | pick [s.t.] up, lift [s.t.]
# Row 7438 is English, bouton, boutons | button, buttons
# Row 7468 is English, mousetrap | mousetrap
# Row 7483 is English, type d'insecte | type of insect
# Row 7513 is English, touchant | touching
# Row 7516 is English, hanche | hip
# Row 7527 is English, hit, smack, whip {sev. times} | hit, smack, whip {sev. times}
# Row 7615 is English, appuyer | press
# Row 7684 is English, mud wall; a siding of mud used to replace grass fencing | mud wall; a siding of mud used to replace grass fencing
# Row 7691 is English, tomate | tomato
# Row 7704 is English, sweet potato planted in dry season and harvested after worst of rains | sweet potato planted in dry season and harvested after worst of rains
# Row 7705 is English, type of hairless caterpillar very destructive to sweet potatoes | type of hairless caterpillar very destructive to sweet potatoes
# Row 7729 is English, Fulani {considered distinct from Mbōrōrō herdsmen} | Fulani {considered distinct from Mbōrōrō herdsmen}
# Row 7748 is English, pin-tailed whydah | pin-tailed whydah
# Row 7791 is English, haricots | beans
# Row 7801 is English, type de haricot | type of bean
# Row 7821 is English, type of large inedible squash [Citrullus lanatus] whose seeds are used for making oil | type of large inedible squash [Citrullus lanatus] whose seeds are used for making oil
# Row 7880 is English, He borrowed Ngaro's bicycle so I could give it to Suu to go make the announcement of Ngaba's death. | He borrowed Ngaro's bicycle so I could give it to Suu to go make the announcement of Ngaba's death.
# Row 7936 is English, Ne marche pas sur mes tomates. | Don't step on my tomatoes.
# Row 7990 is English, sticking up or out | sticking up or out
# Row 8003 is English, cane {for walking} | cane {for walking}
# Row 8045 is English, haricots | beans
# Row 8076 is English, The crowned crane is a river bird. It's a big bird. It has a lot of feathers on its head. People say if you imitate its cry your teeth will grow crooked. | The crowned crane is a river bird.  It's a big bird.  It has a lot of feathers on its head.  People say if you imitate its cry your teeth will grow crooked.
# Row 8077 is English, pin-tailed whydah {small bird with long tail} | pin-tailed whydah {small bird with long tail}
# Row 8083 is English, Abyssinian roller | Abyssinian roller
# Row 8125 is English, type d'herbe [Pennisetum pedicellatum] | type of grass [Pennisetum pedicellatum]
# Row 8127 is English, type d'herbe haute [Pennisetum pedicellatum] | type of tall grass [Pennisetum pedicellatum]
# Row 8144 is English, type d'herbe haute [Andropogon gayanus] | type of tall grass [Andropogon gayanus]
# Row 8155 is English, type d'arbre [Terminalia sp.] | type of tree [Terminalia sp.]
# Row 8158 is English, type d'herbe | type of grass
# Row 8170 is English, type d'arbre [Burkea africana] | type of tree [Burkea africana]
# Row 8200 is English, type de mauvaise herbe [Striga hermonthica] | type of weed [Striga hermonthica]
# Row 8222 is English, type d'herbe | type of grass
# Row 8250 is English, The red-cheeked cordon-bleu is a weaver which is very clever. A snare will rarely catch it. It eats broken up grains around the mortar as well as millet. It's found both in the bush and in the village. | The red-cheeked cordon-bleu is a weaver which is very clever.  A snare will rarely catch it. It eats broken up grains around the mortar as well as millet.  It's found both in the bush and in the village.
# Row 8275 is English, type of large colorful bird {plantain-eater or touraco} | type of large colorful bird {plantain-eater or touraco}
# Row 8287 is English, type of millet {like gɔ̀jɨ̀, its bran is not removed before grinding into flour} | type of millet {like gɔ̀jɨ̀, its bran is not removed before grinding into flour}
# Row 8296 is English, Bodo {principal Gor town, south of Doba} | Bodo {principal Gor town, south of Doba}
# Row 8298 is English, type of millet, which like wàā/bɨ̀nā normally has bran removed (wàā/bɨ̀nā) before grinding into flour | type of millet, which like wàā/bɨ̀nā normally has bran removed (wàā/bɨ̀nā) before grinding into flour
# Row 8310 is English, type d'oriole | type of oriole
# Row 8346 is English, The hornbill is a big bird that sleeps on empty termite hills in the rainy season. Its beak is large in relation to its body. The Mbay say that it also plants peanuts: its peanuts are similar to groundnuts and they're called "hornbill nuts". | The hornbill is a big bird that sleeps on empty termite hills in the rainy season.  Its beak is large in relation to its body.  The Mbay say that it also plants peanuts: its peanuts are similar to groundnuts and they're called "hornbill nuts".
# Row 8352 is English, type of large bird {probably plaintain eater or touraco} | type of large bird {probably plaintain eater or touraco}
# Row 8354 is English, The swallow is a bird that makes its nest in the leaves of the 'palm' tree or in the folds in the tin roofs of people's houses. It eats small insects, and it flies very quickly. | The swallow is a bird that makes its nest in the leaves of the 'palm' tree or in the folds in the tin roofs of people's houses.  It eats small insects, and it flies very quickly.
# Row 8357 is English, type of white-breasted field bird {Senegal coucal} | type of white-breasted field bird {Senegal coucal}
# Row 8363 is English, type of small bird {red bishop, considered variety of gōý-gɨ̄} | type of small bird {red bishop, considered variety of gōý-gɨ̄}
# Row 8368 is English, The parakeet is a small bird whose beak is similar to that of the parrot. It eats sweet fruit and sorghum grains as well. In the dry season, it goes into holes in dead trees and doesn't come out. | The parakeet is a small bird whose beak is similar to that of the parrot.  It eats sweet fruit and sorghum grains as well.  In the dry season, it goes into holes in dead trees and doesn't come out.
# Row 8375 is English, yellow breasted fruit pigeon [Treron australis] or [Treron waalia] | yellow breasted fruit pigeon [Treron australis] or [Treron waalia]
# Row 8380 is English, The laughing dove is slightly larger than the vinaceous dove. They both eat millet, squash, and grass seeds. | The laughing dove is slightly larger than the vinaceous dove.  They both eat millet, squash, and grass seeds.
# Row 8385 is English, The tambourine dove is shorter than the other doves; it's very prudent, and won't die without a good reason. Its food is the same as that of the laughing dove. | The tambourine dove is shorter than the other doves; it's very prudent, and won't die without a good reason.  Its food is the same as that of the laughing dove.
# Row 8398 is English, The Goliath heron is a bird with long legs and a long neck. It eats snakes, fish, crickets and grasshoppers. It sleeps in large trees. | The Goliath heron is a bird with long legs and a long neck.  It eats snakes, fish, crickets and grasshoppers.  It sleeps in large trees.
# Row 8405 is English, common nightjar | common nightjar
# Row 8429 is English, gobemouche | flycatcher
# Row 8450 is English, great white egret [Egretta alba] | great white egret [Egretta alba]
# Row 8454 is English, chouette chevêche [Otus scops] | scops owl [Otus scops]
# Row 8459 is English, mourning dove | mourning dove
# Row 8460 is English, tout cela (manger). | all of it (eat).
# Row 8491 is English, tomber lourdement | heavily (fall).
# Row 8628 is English, thoroughly (essuyer). | thoroughly (wipe).
# Row 8704 is English, avec un choc ; avec force (choc, crash). | with a shock; with force (bump, crash).
# Row 8719 is English, up and down (fall); down (duck) | up and down (fall); down (duck)
# Row 8757 is English, beaucoup (manger) | a lot (eat).
# Row 8775 is English, grand ouvert (bouche) | wide open (mouth).
# Row 8851 is English, tout (blanc). | all (white).
# Row 8873 is English, season | season for
# Row 8885 is English, The child swallowed the 'boule' quickly and in huge gulps. | The child swallowed the 'boule' quickly and in huge gulps.
# Row 9031 is English, incapable de bouger | unable to move.
# Row 9056 is English, We stayed two years in Central Africa, left Central Africa and came to Sarh. In Sarh we stayed three years, then we left Sarh and went to stay in Beboro. | We stayed two years in Central Africa, left Central Africa and came to Sarh.  In Sarh we stayed three years, then we left Sarh and went to stay in Beboro.
# Row 9082 is English, toc-toc | knock-knock
# Row 9212 is English, dur (tomber) | hard (fall).
# Row 9228 is English, fermement (attacher, fixer) | firmly (tie, attach).
# Row 9230 is English, beaucoup (trop grand pour) | much (too big for).
# Row 9244 is English, mal, beaucoup (gonfler, se lever). | badly, a lot (swell, rise up).
# Row 9263 is English, ne pas ramifier (arbre, branche, bûche, etc.) | be not branching (tree, branch, log, etc.)
# Row 9292 is English, J'ai failli tomber sur toi. | I almost fell on you.
# Row 9386 is English, terribly (unlucky); completely (be a failure) | terribly (unlucky); completely (be a failure)
# Row 9429 is English, type d'herbe haute [Rottboellia exaltata] | type of tall grass [Rottboellia exaltata]
# Row 9431 is English, type of mourning dove {red-eyed dove?} | type of mourning dove {red-eyed dove?}
# Row 9448 is English, afficher | show
# Row 9473 is English, Gundi {Tumak capital, north of Koumra} | Gundi {Tumak capital, north of Koumra}
# Row 9483 is English, Bedaya {important Sar town between Koumra and Sarh} | Bedaya {important Sar town between Koumra and Sarh}
# Row 9488 is English, nuages | clouds
# Row 9503 is English, poser [charge] | put down [load]
# Row 9506 is English, harvest ['small millet',corn] {by breaking off head} | harvest ['small millet',corn] {by breaking off head}
# Row 9579 is English, syphilis | syphilis
# Row 9660 is English, press to, hug; steal; become friends with | press to, hug; steal; become friends with
# Row 9705 is English, sling for throwing rocks {arq.} | sling for throwing rocks {arq.}
# Row 9764 is English, covetousness, greed | covetousness, greed
# Row 9812 is English, dispute with | dispute with
# Row 9913 is English, Un orage approche. | A thunderstorm is coming.
# Row 9986 is English, moped, small motorcycle | moped, small motorcycle
# Row 10022 is English, swallowing | swallowing; pounding; grind; digging, etc.
# Row 10063 is English, force | force
# Row 10072 is English, char; burn | char; burn
# Row 10141 is English, type of large colorful bird {plantain-eater or touraco} | type of large colorful bird {plantain-eater or touraco}
# Row 10159 is English, tornade, petit tourbillon | twister, little tornado
# Row 10161 is English, He handed two to Sand, but refused to give any to Fire. | He handed two to Sand, but refused to give any to Fire.
# Row 10197 is English, type of large-leafed dark violet hibiscus whose bark is used in making rope [hibiscus cannabinus] | type of large-leafed dark violet hibiscus whose bark is used in making rope [hibiscus cannabinus]
# Row 10234 is English, cacher | hide
# Row 10236 is English, se cacher {intransitif} | hide {intransitive}
# Row 10347 is English, screech, hoot, cry; roar, growl, etc. | screech, hoot, cry; roar, growl, etc.
# Row 10364 is English, The child I hit and who ran back home is the son of my neighbor. | The child I hit and who ran back home is the son of my neighbor.
# Row 10389 is English, tentation {chr.} | temptation {chr.}
# Row 10432 is English, type d'herbe [Imperata cylandrica] | type of grass [Imperata cylandrica]
# Row 10434 is English, support {by being stuck in ground} | support {by being stuck in ground}
# Row 10456 is English, type d'herbe haute [Andropogon gayanus] | type of tall grass [Andropogon gayanus]
# Row 10458 is English, mucus {in stool} | mucus {in stool}
# Row 10463 is English, chasse | hunting
# Row 10466 is English, quill {porcupine, hedgehog} | quill {porcupine, hedgehog}
# Row 10479 is English, pied crow [Corvus albus] | pied crow [Corvus albus]
# Row 10533 is English, Paris {important Day town, 53 kms. west of Moissala} | Paris {important Day town, 53 kms. west of Moissala}
# Row 10567 is English, trick {cards} | trick {cards}
# Row 10569 is English, relationship | relationship, friendship
# Row 10580 is English, type of poisonous snake {cobra, 'spitting snake'} | type of poisonous snake {cobra, 'spitting snake'}
# Row 10680 is English, formation militaire | military formation

# %%
print(len(cells))
cells
# Out:
# 254
# [<Cell R369C5 'morceau [de tissu]'>,
#  <Cell R404C5 "type d'escargot, coquille utilisée dans un jeu de hasard">,
#  <Cell R471C5 'traire; essorer; etc.'>,
#  <Cell R511C5 'chasse collective'>,
#  <Cell R565C5 'amateur de chasse / combat / pêche'>,
#  <Cell R626C5 'balle de nourriture pour animaux {herbes et feuilles séchées et liées}; fourrage'>,
#  <Cell R783C5 'insecte flétrisseur de brindilles {insecte aux pattes bizarrement formées, qui suce la sève des plantes}'>,
#  <Cell R810C5 'idiot, imbécile'>,
#  <Cell R832C5 'propreté, clarté, luminosité'>,
#  <Cell R994C5 'infirme'>,
#  <Cell R996C5 'pleureur public'>,
#  <Cell R1000C5 'Chrétien {lit: celui qui a promis}'>,
#  <Cell R1006C5 'commérage, personne qui commère'>,
#  <Cell R1081C5 'peau, cuir'>,
#  <Cell R1164C5 'buisson épineux; arbre [Acacia ataxacantha] et [Acacia macrostachya]'>,
#  <Cell R1176C5 "type de manioc légèrement amer d'origine centrafricaine; plus couramment cultivé">,
#  <Cell R1193C5 'chenille poilue {non comestible et destructrice}'>,
#  <Cell R1241C5 'cousin germain maternel'>,
#  <Cell R1319C5 'peau, cuir'>,
#  <Cell R1346C5 'front'>,
#  <Cell R1368C5 'tirer vers le haut; brûler; etc.'>,
#  <Cell R1374C5 'sucer, manger [fruit juteux, sauce]'>,
#  <Cell R1401C5 "type de petit mille-pattes noir, morsure encore plus douloureuse que celle d'un mille-pattes normal">,
#  <Cell R1403C5 'sorts et fétiches liés à la chasse et à la pêche'>,
#  <Cell R1453C5 'acheter'>,
#  <Cell R1532C5 'lance à poisson barbelé ou harpon'>,
#  <Cell R1617C5 'brasserie, bar local'>,
#  <Cell R1717C5 'refus; refusant'>,
#  <Cell R1739C5 'regarder fixement, lancer un regard noir [à qqn]'>,
#  <Cell R1800C5 'regarder fixement, jeter un regard noir [à qqn]'>,
#  <Cell R1804C5 'sauterelle, criquet (très grand, comestible)'>,
#  <Cell R1839C5 'Cinquante (250 FCFA) et je me suis acheté des chaussures avec.'>,
#  <Cell R1871C5 'Le sort pour protéger un champ {contre le vol} est des bâtons croisés.'>,
#  <Cell R1881C5 "La chauve-souris fruitière est un petit oiseau qui ne mange que des mangues. Les gens la mangent. Elle a bon goût. Elle n'a pas beaucoup de viande, elle est très osseuse.">,
#  <Cell R1914C5 'coucher à droite et à gauche; vivre une vie débauchée'>,
#  <Cell R1963C5 'assiette, plat, bol'>,
#  <Cell R2110C5 'assistant du boucher'>,
#  <Cell R2378C5 'piège à souris'>,
#  <Cell R2399C5 'corbeau pie [Corvus albus]'>,
#  <Cell R2459C5 "Le lézard de maison ressemble au lézard de cour, mais son extérieur est brillant. Il se trouve à côté des pots d'eau parce qu'il aime les endroits frais. Les gens disent que si vous les tuez souvent, vous n'aurez plus de force.">,
#  <Cell R2537C5 'Le tubercule de cette plante est similaire à celui de la pomme de terre finger, mais le premier est rond et a une extérieur rouge.'>,
#  <Cell R2588C5 'célibataire, femme célibataire'>,
#  <Cell R2600C5 'placer à travers, définir à travers'>,
#  <Cell R2620C5 "Une sauterelle est un insecte qui mange des feuilles d'herbe; certaines d'entre elles sont mangées par des personnes.">,
#  <Cell R2766C5 "La petite grenouille de rivière vit dans des étangs ou dans l'herbe. Les gens la mangent. Son corps est rouge.">,
#  <Cell R2842C5 'type de balai fait de branches {utilisé pour balayer le sol des composés}'>,
#  <Cell R2899C5 "bosse; s'encastrer">,
#  <Cell R2923C5 'pierre de foyer'>,
#  <Cell R3020C5 'rites, fétiches, traditions'>,
#  <Cell R3025C5 "type de gros rat de maison gris qui a envahi la région Mbay en provenance d'Afrique centrale">,
#  <Cell R3082C5 'nom masculin {avec des jumeaux, soit précédant un deuxième jumeau masculin (Ngābà/Kōrōó), soit suivant une jumelle (Ngābà/Kōrōó)}'>,
#  <Cell R3083C5 'merci; Dieu merci; profitez de votre nourriture'>,
#  <Cell R3128C5 'vigoureusement (bouillir) {avec une substance en agitation dans un liquide}'>,
#  <Cell R3130C5 'poitrine de chèvre {considérée comme la portion la plus délicieuse}'>,
#  <Cell R3133C5 'corde de filet passée à travers le bas du filet de pêche entre deux poteaux sur les côtés'>,
#  <Cell R3139C5 'jeune femme charmante {lit: le centre de la charmant}'>,
#  <Cell R3168C5 'corbeau pie [Corvus albus]'>,
#  <Cell R3439C5 "pièce à l'arrière {loin de la porte}">,
#  <Cell R3467C5 'morceau de sucre / sel gemme / bouillie / tapioca'>,
#  <Cell R3490C5 'moelleux, chair humide [de certains fruits]'>,
#  <Cell R3512C5 'force, puissance'>,
#  <Cell R3543C5 'Le chef était le tout premier à faire peser son coton.'>,
#  <Cell R3571C5 'Les boulettes de haricots sont des haricots écrasés enveloppés dans une feuille.'>,
#  <Cell R3612C5 "se secouant; se précipitant; se dandinant d'avant en arrière">,
#  <Cell R3613C5 "secouant, se dandinant d'avant en arrière">,
#  <Cell R3671C5 'vélo'>,
#  <Cell R3676C5 'importance, chose ou personne importante'>,
#  <Cell R3862C5 "Les gens appellent le fouet fait de branches de 'gommier' 'Borbonde'.">,
#  <Cell R3872C5 'manioc [lit: igname de cotonnier]'>,
#  <Cell R3887C5 'vieux seins défraîchis et flasques {argot}'>,
#  <Cell R3903C5 'lunettes de soleil {lit: regarder votre belle-mère}'>,
#  <Cell R4084C5 'envies; ongle incarné; toute plaie autour des ongles'>,
#  <Cell R4198C5 'dressé et sale (cheveux)'>,
#  <Cell R4230C5 'ganglion, infection dans une partie du corps causée par une blessure dans une zone avoisinante'>,
#  <Cell R4248C5 "fauteur de troubles {lit: Je l'ai vu, je leur ai dit}">,
#  <Cell R4257C5 'criquet femelle'>,
#  <Cell R4268C5 'offre, proposer de donner'>,
#  <Cell R4274C5 'cobe à croissant, defassa [Kobus ellipsiprymnus]'>,
#  <Cell R4307C5 "type de charme ('gri-gri'), normalement conservé dans une petite pochette en cuir et porté autour du cou sur une ficelle">,
#  <Cell R4426C5 'type de chenille comestible, considérée particulièrement savoureuse'>,
#  <Cell R4427C5 "type de chenille comestible sans poils trouvée sur l'arbre njúwá">,
#  <Cell R4529C5 'coffre, valise {pour transporter ou ranger des vêtements}'>,
#  <Cell R4538C5 'chasser {fig.}'>,
#  <Cell R4611C5 'guib harnaché [Tragelaphus scriptus]'>,
#  <Cell R4757C5 'carboniser, brûler; être carbonisé, brûlé'>,
#  <Cell R4816C5 'tapis fin qui peut être enroulé {tissé dans le nord et vendu par des marchands musulmans}'>,
#  <Cell R4825C5 'trône, chaise [pour chef]'>,
#  <Cell R4847C5 'village, ville ; chez soi'>,
#  <Cell R4860C5 "type de serpent venimeux {cobra, serpent 'cracheur'}">,
#  <Cell R4920C5 'pinces {de forgeron}'>,
#  <Cell R4939C5 "écraser [grain] {pour enlever l'enveloppe ou la balle}">,
#  <Cell R4959C5 'type de grand bassin'>,
#  <Cell R5070C5 'Tchad'>,
#  <Cell R5140C5 'type de petit tambour composé de deux petits tambours attachés ensemble'>,
#  <Cell R5186C5 'valet (cartes)'>,
#  <Cell R5187C5 'valet de pique/cœur/carreau/trèfle'>,
#  <Cell R5190C5 "La femme a rassemblé un tas de cendres de feuilles et y a versé de l'eau afin de fabriquer du sel.">,
#  <Cell R5222C5 'tige de cacahuète'>,
#  <Cell R5276C5 'anse, section de rivière, courbe'>,
#  <Cell R5311C5 'petit arbre non développé/champignon/plant de coton'>,
#  <Cell R5369C5 "La sauce 'Goylo' est faite de haricots cuits avec de la farine tandis que 'guwse' est des haricots cuits dans une 'longue sauce'.">,
#  <Cell R5370C5 "boum-boum-boum {son d'une batterie}">,
#  <Cell R5408C5 'coton-tige'>,
#  <Cell R5559C5 'rat de canne [Thryonomys swinderianus]'>,
#  <Cell R5578C5 'sueur'>,
#  <Cell R5616C5 'Un sort est quelque chose utilisé par les gens pour protéger leurs champs.'>,
#  <Cell R5660C5 "piège fabriqué à partir des poils de la queue d'un animal">,
#  <Cell R5714C5 'syphilis'>,
#  <Cell R5753C5 'secouer, bouger'>,
#  <Cell R5770C5 'cherchez attentivement, passez au crible'>,
#  <Cell R5874C5 'thermos'>,
#  <Cell R5894C5 'gilet court {porté par les cavaliers ou par les citadins}'>,
#  <Cell R6080C5 'passer sans entrer [piège]'>,
#  <Cell R6089C5 'cœurs {couleur dans les cartes}'>,
#  <Cell R6096C5 'trèfles {couleur dans les cartes}'>,
#  <Cell R6155C5 'type de poisson-chat [Chrysichthys auratus]'>,
#  <Cell R6156C5 'type de poisson-chat [Auchenoglanis biscutatus]'>,
#  <Cell R6159C5 'type de poisson-chat [Bagrus bayad]'>,
#  <Cell R6161C5 'céphalophe à flancs roux [Cephalophus rufilatus]'>,
#  <Cell R6179C5 'antilope rouanne [Hippotragus equinus]'>,
#  <Cell R6201C5 'céphalophe gris ou commun [Cephalophus grimmia]'>,
#  <Cell R6203C5 "{Proverbe} Si tu n'as pas attrapé un céphalophe, as-tu coupé la corde? {Il ne faut pas vendre la peau de l'ours avant de l'avoir tué.}">,
#  <Cell R6291C5 'force, puissance'>,
#  <Cell R6338C5 'argent; payer'>,
#  <Cell R6362C5 'libellule {qui apparaît en saison sèche}'>,
#  <Cell R6370C5 'La femme a détruit la termitière pour fabriquer des pierres de foyer.'>,
#  <Cell R6378C5 'glanage; parasitisme'>,
#  <Cell R6411C5 'divorce [mari]'>,
#  <Cell R6459C5 "Il a économisé son argent jusqu'à ce qu'il ait sept cent soixante-dix-sept mille, sept cent soixante-dix-sept.">,
#  <Cell R6528C5 'cracher'>,
#  <Cell R6534C5 "puis {indique que la clause précédente se produit avant la clause suivante : normalement suivie d'une clause lā...yé}">,
#  <Cell R6644C5 'cot cot {cri de la poule}'>,
#  <Cell R6660C5 'nom féminin {souvent donné à la jumelle née en seconde, dont le premier est un garçon <nommé Ngāró>}'>,
#  <Cell R6675C5 'Kotoko {peuple habitant les zones fluviales près de Ndjamena}'>,
#  <Cell R6801C5 'bouchon de bouteille (normalement de bière)'>,
#  <Cell R6835C5 "type d'arbre [Strychnos sp.]">,
#  <Cell R6874C5 'Cet arbre est utilisé pour fabriquer de la corde pour les toits ainsi que pour tisser des clôtures en herbe.'>,
#  <Cell R6880C5 'Les gens mangent le fruit de ce buisson. Les chèvres mangent ses feuilles, les gens mangent ses fruits.'>,
#  <Cell R6885C5 "type d'herbe [Imperata cylindrica]">,
#  <Cell R6893C5 'type de grand arbre [Daniellia oliveri]'>,
#  <Cell R6900C5 "type d'arbre {probablement [Canarium schweinfurthii]}">,
#  <Cell R6904C5 "type d'herbe [Eleusine indica]">,
#  <Cell R6958C5 'bosse [vache, chameau]'>,
#  <Cell R6965C5 'massue {pour la pêche}'>,
#  <Cell R7014C5 'La chemise sans manches est une chemise pour les cavaliers.'>,
#  <Cell R7024C5 'arbre à coton (généralement appelé arbre à kapok) [Ceiba pentandra]'>,
#  <Cell R7031C5 "type d'arbre [Jatropha sp.]">,
#  <Cell R7035C5 "type d'herbe">,
#  <Cell R7066C5 "Cette plante est utilisée pour fabriquer des clôtures en herbe. Ses feuilles sont écrasées dans l'eau pour la rendre acidulée pour la boisson.">,
#  <Cell R7067C5 "type d'herbe [Sansevieria liberica]">,
#  <Cell R7081C5 "type d'herbe">,
#  <Cell R7083C5 "type d'arbre [Amblygonocarpus andongensis]">,
#  <Cell R7100C5 'type de palmier [Borassus aethiopum]'>,
#  <Cell R7113C5 'type de grande herbe, utilisée dans la fabrication de clôtures en herbe [Cymbopogon giganteus]'>,
#  <Cell R7140C5 'type de buisson [Crotalaria sp.]'>,
#  <Cell R7194C5 'palmier dum [Hyphaene thebaica]'>,
#  <Cell R7207C5 "type d'arbre [Sclerocarya birrea]">,
#  <Cell R7236C5 "type d'herbe">,
#  <Cell R7330C5 "type d'insecte">,
#  <Cell R7353C5 "pilonner, moudre [grain] {pour enlever le son; réalisé avec un peu d'eau}">,
#  <Cell R7418C5 'ramasser [qch], soulever [qch]'>,
#  <Cell R7438C5 'bouton, boutons'>,
#  <Cell R7468C5 'piège à souris'>,
#  <Cell R7483C5 "type d'insecte">,
#  <Cell R7513C5 'touchant'>,
#  <Cell R7516C5 'hanche'>,
#  <Cell R7527C5 'frapper, gifler, fouetter {plusieurs fois}'>,
#  <Cell R7615C5 'presse'>,
#  <Cell R7684C5 'mur de boue; un revêtement de boue utilisé pour remplacer une clôture en herbe'>,
#  <Cell R7691C5 'tomate'>,
#  <Cell R7704C5 'patate douce plantée en saison sèche et récoltée après les pires pluies'>,
#  <Cell R7705C5 'type de chenille sans poils très destructrice pour les patates douces'>,
#  <Cell R7729C5 'Fulani {considéré distinct des éleveurs Mbōrōrō}'>,
#  <Cell R7748C5 'Veuve dominicaine'>,
#  <Cell R7791C5 'haricots'>,
#  <Cell R7801C5 'type de haricot'>,
#  <Cell R7821C5 "type de grosse courge non comestible [Citrullus lanatus] dont les graines sont utilisées pour faire de l'huile">,
#  <Cell R7880C5 "Il a emprunté le vélo de Ngaro pour que je puisse le donner à Suu pour aller faire l'annonce de la mort de Ngaba.">,
#  <Cell R7936C5 'Ne marche pas sur mes tomates.'>,
#  <Cell R7990C5 'dépassant ou ressortant'>,
#  <Cell R8003C5 'canne {pour marcher}'>,
#  <Cell R8076C5 "La grue couronnée est un oiseau de rivière. C'est un gros oiseau. Il a beaucoup de plumes sur la tête. Les gens disent que si vous imitez son cri, vos dents pousseront de travers.">,
#  <Cell R8077C5 'Veuve dominicaine {petit oiseau à longue queue}'>,
#  <Cell R8083C5 "Rollier d'Abyssinie">,
#  <Cell R8250C5 'Le cordon-bleu à joues rouges est un tisserand qui est très intelligent. Un piège le capturera rarement. Il mange des grains cassés autour du mortier ainsi que du millet. On le trouve à la fois dans la brousse et dans le village.'>,
#  <Cell R8275C5 'type de grand oiseau coloré {mangeur de bananes ou touraco}'>,
#  <Cell R8287C5 "type de millet {comme le gɔ̀jɨ̀, son son n'est pas retiré avant d'être moulu en farine}">,
#  <Cell R8296C5 'Bodo {ville principale de Gor, au sud de Doba}'>,
#  <Cell R8298C5 "type de millet, qui comme le wàā/bɨ̀nā a normalement le son enlevé (wàā/bɨ̀nā) avant d'être moulu en farine">,
#  <Cell R8310C5 "type d'oriole">,
#  <Cell R8346C5 'Le calao est un grand oiseau qui dort sur des collines de termites vides pendant la saison des pluies. Son bec est grand par rapport à son corps. Les Mbay disent qu\'il plante aussi des arachides : ses arachides sont similaires aux cacahuètes et elles sont appelées "noix de calao".'>,
#  <Cell R8352C5 'type de grand oiseau {probablement mangeur de plantains ou touraco}'>,
#  <Cell R8354C5 "L'hirondelle est un oiseau qui fait son nid dans les feuilles de l'arbre 'palmier' ou dans les plis des toits en tôle des maisons des gens. Elle mange de petits insectes et vole très rapidement.">,
#  <Cell R8357C5 "type d'oiseau de champ à poitrine blanche {coucal du Sénégal}">,
#  <Cell R8363C5 'type de petit oiseau {évêque rouge, considéré comme une variété de gōý-gɨ̄}'>,
#  <Cell R8368C5 "La perruche est un petit oiseau dont le bec ressemble à celui du perroquet. Elle se nourrit de fruits sucrés et de graines de sorgho. Pendant la saison sèche, elle se réfugie dans les trous des arbres morts et n'en sort pas.">,
#  <Cell R8375C5 'pigeon fruitier à poitrine jaune [Treron australis] ou [Treron waalia]'>,
#  <Cell R8380C5 "La tourterelle rieuse est légèrement plus grande que la tourterelle vineuse. Elles mangent toutes deux du millet, de la courge et des graines d'herbe.">,
#  <Cell R8385C5 'La tourterelle tambourine est plus petite que les autres tourterelles ; elle est très prudente et ne mourra pas sans une bonne raison. Sa nourriture est la même que celle de la tourterelle rieuse.'>,
#  <Cell R8398C5 'Le héron Goliath est un oiseau aux longues pattes et au long cou. Il mange des serpents, des poissons, des grillons et des sauterelles. Il dort dans de grands arbres.'>,
#  <Cell R8405C5 "engoulevent d'Europe">,
#  <Cell R8429C5 'attrape-mouche'>,
#  <Cell R8450C5 'grande aigrette blanche [Egretta alba]'>,
#  <Cell R8454C5 'hibou petit-duc [Otus scops]'>,
#  <Cell R8459C5 'tourterelle triste'>,
#  <Cell R8460C5 'tout cela (mange).'>,
#  <Cell R8491C5 'lourdement (tomber).'>,
#  <Cell R8628C5 'soigneusement (essuyer).'>,
#  <Cell R8704C5 'avec un choc; avec force (coup, crash)'>,
#  <Cell R8719C5 'haut et bas (chute); bas (esquive)'>,
#  <Cell R8873C5 'saison pour'>,
#  <Cell R8885C5 "L'enfant a avalé la 'boule' rapidement et à grandes gorgées.">,
#  <Cell R9031C5 'incapable de bouger.'>,
#  <Cell R9056C5 "Nous sommes restés deux ans en Afrique Centrale, avons quitté l'Afrique Centrale et sommes venus à Sarh. À Sarh, nous sommes restés trois ans, puis nous avons quitté Sarh et sommes allés vivre à Beboro.">,
#  <Cell R9082C5 'toc-toc'>,
#  <Cell R9244C5 'mal, beaucoup (gonfler, se lever).'>,
#  <Cell R9263C5 'ne pas se ramifier (arbre, branche, bûche, etc.)'>,
#  <Cell R9292C5 "J'ai failli tomber sur toi.">,
#  <Cell R9386C5 'terriblement (malchanceux); complètement (être un échec)'>,
#  <Cell R9429C5 'type de grande herbe [Rottboellia exaltata]'>,
#  <Cell R9431C5 'type de tourterelle en deuil {tourterelle à œil rouge?}'>,
#  <Cell R9448C5 'spectacle'>,
#  <Cell R9473C5 'Gundi {capitale de Tumak, au nord de Koumra}'>,
#  <Cell R9483C5 'Bedaya {ville importante de Sar située entre Koumra et Sarh}'>,
#  <Cell R9488C5 'nuages'>,
#  <Cell R9503C5 'poser [charge]'>,
#  <Cell R9506C5 "récolte ['petit mil', maïs] {en cassant la tête}">,
#  <Cell R9579C5 'syphilis'>,
#  <Cell R9660C5 'appuyer sur, étreindre; voler; devenir ami avec'>,
#  <Cell R9705C5 'fronde pour lancer des pierres {arq.}'>,
#  <Cell R9764C5 'cupidité, avidité'>,
#  <Cell R9812C5 'différend avec'>,
#  <Cell R9913C5 'Un orage arrive.'>,
#  <Cell R9986C5 'mobylette, petite moto'>,
#  <Cell R10022C5 'avaler; marteler; moudre; creuser, etc.'>,
#  <Cell R10063C5 'force'>,
#  <Cell R10072C5 'carboniser; brûler'>,
#  <Cell R10141C5 'type de grand oiseau coloré {mangeur de plantain ou touraco}'>,
#  <Cell R10159C5 'tornade, petite tornade'>,
#  <Cell R10161C5 "Il en a donné deux à Sable, mais a refusé d'en donner à Feu.">,
#  <Cell R10197C5 "type d'hibiscus à grandes feuilles violettes foncé dont l'écorce est utilisée pour fabriquer de la corde [hibiscus cannabinus]">,
#  <Cell R10234C5 'cacher'>,
#  <Cell R10347C5 'crissement, hululement, cri; rugissement, grondement, etc.'>,
#  <Cell R10364C5 "L'enfant que j'ai frappé et qui est rentré chez lui est le fils de mon voisin.">,
#  <Cell R10389C5 'tentation {chr.}'>,
#  <Cell R10434C5 'soutien {en étant coincé dans le sol}'>,
#  <Cell R10458C5 'mucus {dans les selles}'>,
#  <Cell R10466C5 'plume {porc-épic, hérisson}'>,
#  <Cell R10479C5 'corbeau pie [Corvus albus]'>,
#  <Cell R10533C5 "Paris {ville importante de Day, à 53 kms à l'ouest de Moissala}">,
#  <Cell R10567C5 'tour {cartes}'>,
#  <Cell R10569C5 'relation, amitié'>,
#  <Cell R10580C5 "type de serpent venimeux {cobra, 'serpent cracheur'}">,
#  <Cell R10680C5 'formation militaire'>]

# %%
sheet.update_cells(cells)
# Out:
# {'spreadsheetId': '1KbpQS0RdcLhUOJNFNdXlnTDZBKEU2S8Q7DnJhPYrr2M',
#  'updatedRange': "'mbay-translations-review'!E369:E10680",
#  'updatedRows': 254,
#  'updatedColumns': 1,
#  'updatedCells': 254}

# %%
# entries = [
#     d.Entry(**entry)
#     for entry in client.get_database("dictionary").get_collection("entries").find()
# ]
